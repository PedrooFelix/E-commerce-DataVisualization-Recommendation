# %% [markdown]
# # Importing Libraries

# %%
                                                                        '''
                                                        All of the libraries that i used.
                                                                     '''

#sqlalchemy: to do the connection to PostgreSQL
import sqlalchemy as db 

#psysicopg2: also do the same 
import psycopg2

#os: operating system: to change the directory
import os

#selenium: to do the webscrapping
import selenium
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.keys import Keys

#requests: to do the url requests
import requests

#time: to do some calls doing the sleep function
import time

#multiprocess: to do some scrapping using my pc
from multiprocess import Pool

#pandas: to do all things involved operating tables
import pandas as pd

#BeautifulSoup: to do some searchs in the web
from bs4 import BeautifulSoup

#numpy is the library where i can use the 
import numpy as np

# %% [markdown]
# # Connecting to postgreSQL

# %%
#GET THE LOCAL OF THE SERVER THAT YOU WANT TO CONNECT
engine = db.create_engine('postgresql://postgres:admin@localhost/olist')
# localhost = 127.0.0.1
# open the connection
conn = engine.connect()

# %% [markdown]
# ## uploading the dataset to postgreeSQL

# %%
for f in os.listdir('archive'):
    x = pd.read_csv(f'archive/{f}',low_memory=False)
    x.to_sql(name=f.replace('.csv',''), con=conn, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-fc90cd62b04d> in <module>
#       1 for f in os.listdir('archive'):
#       2     x = pd.read_csv(f'archive/{f}',low_memory=False)
# ----> 3     x.to_sql(name=f.replace('.csv',''), con=conn, if_exists='replace', index=False)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ...

# %% [markdown]
# # Webscrapping:

# %%
#the site selected is google trends
url = 'https://trends.google.com.br/trends'

# %% [markdown]
# ## for do the query in trends i will use the category name from a query of the dataset in postgreSQL

# %%
rows = pd.read_sql_query('SELECT product_category_name FROM product_category_name_translation;', con=conn)

# %%
# check the dataframe
rows
# Out:
#             product_category_name
# 0                    beleza_saude
# 1          informatica_acessorios
# 2                      automotivo
# 3                 cama_mesa_banho
# 4                moveis_decoracao
# ..                            ...
# 66                         flores
# 67             artes_e_artesanato
# 68                fraldas_higiene
# 69  fashion_roupa_infanto_juvenil
# 70             seguros_e_servicos
#
# [71 rows x 1 columns]

# %%
# transposing the dataset transforming the columns into rows
rows = rows.T

# %%
# making my query in the google trends
pesquisa = ' e '.join(rows[0][::][0].split('_'))

# %%
#checking the query
pesquisa
# Out:
# 'beleza e saude'

# %%
#WHERE I'LL SAVE THE DATAFRAME
df= pd.DataFrame(columns=['resposta'])

# %%
driver = webdriver.Safari()
driver.get(url) 
driver.maximize_window()

for i in range(len(rows.T)-1):
    time.sleep(2)
    pesquisa = ' e '.join(rows[i][0:1][0].split('_'))
    elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/ng-include/div/div[2]/autocomplete/md-autocomplete/md-autocomplete-wrap/input')
    elem.send_keys(pesquisa)
    elem.send_keys(Keys.RETURN)
    time.sleep(2.5)
    elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/header/div/div[3]/ng-transclude/div[2]/div/div/custom-date-picker/ng-include/md-select/md-select-value/span[2]')     
    elem.click()
    time.sleep(1)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.RETURN)
    time.sleep(1.5)
    elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[1]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]')
    elem.click()
    time.sleep(2.5)
    elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[2]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]/i')
    elem.click()
    time.sleep(2)
    driver.get(url)

# %% [markdown]
# # Tuning the table to do awesome visualizations!

# %% [markdown]
# ## getting the dataframe from the downloaded geomap

# %%
geograph = [i for i in os.listdir('/Users/usuario/Downloads') if i.startswith('geoMap-')]

# %% [markdown]
# ## passing to a dataframe

# %%
datageo = pd.DataFrame(columns=['product_category_name', 'Mato Grosso do Sul', 'Goiás', 'Santa Catarina', 'Pernambuco',
   'Bahia', 'Distrito Federal', 'Ceará', 'São Paulo', 'Rio Grande do Sul',
   'Rio de Janeiro', 'Paraná', 'Minas Gerais', 'Amapá', 'Rondônia',
   'Piauí', 'Mato Grosso', 'Espírito Santo', 'Pará', 'Paraíba', 'Sergipe',
   'Maranhão', 'Alagoas', 'Amazonas', 'Acre', 'Rio Grande do Norte',
   'Roraima', 'Tocantins'])
for i in geograph:
    csv = pd.read_csv(f'/Users/usuario/Downloads/{i}')
    csv = csv.T
    csv.columns = ['product_category_name', 'Mato Grosso do Sul', 'Goiás', 'Santa Catarina', 'Pernambuco',
       'Bahia', 'Distrito Federal', 'Ceará', 'São Paulo', 'Rio Grande do Sul',
       'Rio de Janeiro', 'Paraná', 'Minas Gerais', 'Amapá', 'Rondônia',
       'Piauí', 'Mato Grosso', 'Espírito Santo', 'Pará', 'Paraíba', 'Sergipe',
       'Maranhão', 'Alagoas', 'Amazonas', 'Acre', 'Rio Grande do Norte',
       'Roraima', 'Tocantins']
    datageo=pd.concat([datageo,csv], ignore_index=True)

# %% [markdown]
# ## because the product category name doesnt came correctly i will do this:

# %%
datageo.product_category_name = datageo['product_category_name'].str.split(':').str[0].str.replace(' e ','_')

# %%
## Transposing the datageo and checking the datageo

# %%
datageo = datageo.T
datageo

# %%
dataframegeo = pd.DataFrame()

# %% [markdown]
# ## Because tableau dont get the data accurately, i will need to this dataframe with the category matching the the column.

# %%
for i in datageo2.columns:
    ##deep copy = faz a copia real do dataframe, ao invez de dar um novo endereço
    df = datageo2[[i]].copy()
    df.columns=['values']
    df['product_category_name']=i

# %%
datageo.to_sql(name='datageo', con=conn, if_exists='replace', index=False)

# %%
datageo2 = datageo.set_index('product_category_name').T

# %% [markdown]
# ## lets do the same with the words downloaded

# %%
palavra = [i for i in os.listdir('/Users/usuario/Downloads') if i.startswith('multiTimeline')]

# %%
#checking
palavra
# Out:
# ['multiTimeline-23.csv',
#  'multiTimeline-37.csv',
#  'multiTimeline-36.csv',
#  'multiTimeline-22.csv',
#  'multiTimeline-34.csv',
#  'multiTimeline-20.csv',
#  'multiTimeline-21.csv',
#  'multiTimeline-35.csv',
#  'multiTimeline-19.csv',
#  'multiTimeline-31.csv',
#  'multiTimeline-25.csv',
#  'multiTimeline-24.csv',
#  'multiTimeline-30.csv',
#  'multiTimeline-18.csv',
#  'multiTimeline-26.csv',
#  'multiTimeline-32.csv',
#  'multiTimeline-33.csv',
#  'multiTimeline-27.csv',
#  'multiTimeline-40.csv',
#  'multiTimeline-54.csv',
#  'multiTimeline-68.csv',
#  'multiTimeline-69.csv',
#  'multiTimeline-55.csv',
#  'multiTimeline-41.csv',
#  'multiTimeline-57.csv',
#  'multiTimeline-43.csv',
#  'multiTimeline-42.csv',
#  'multiTimeline-56.csv',
#  'multiTimeline-52.csv',
#  'multiTimeline-46.csv',
#  'multiTimeline-47.csv',
#  'multiTimeline-53.csv',
#  'multiTimeline-45.csv',
#  'multiTimeline-51.csv',
#  'multiTimeline-50.csv',
#  'multiTimeline-44.csv',
#  'multiTimeline-61.csv',
# ...

# %%
words_final = pd.DataFrame(columns=['product_category_name','2016-02-21','2016-02-28','2016-03-06','2016-03-13','2016-03-20','2016-03-27','2016-04-03','2016-04-10','2016-04-17','2016-04-24','2016-05-01','2016-05-08','2016-05-15','2016-05-22','2016-05-29','2016-06-05','2016-06-12','2016-06-19','2016-06-26','2016-07-03','2016-07-10','2016-07-17','2016-07-24','2016-07-31','2016-08-07','2016-08-14','2016-08-21','2016-08-28','2016-09-04','2016-09-11','2016-09-18','2016-09-25','2016-10-02','2016-10-09','2016-10-16','2016-10-23','2016-10-30','2016-11-06','2016-11-13','2016-11-20','2016-11-27','2016-12-04','2016-12-11','2016-12-18','2016-12-25','2017-01-01','2017-01-08','2017-01-15','2017-01-22','2017-01-29','2017-02-05','2017-02-12','2017-02-19','2017-02-26','2017-03-05','2017-03-12','2017-03-19','2017-03-26','2017-04-02','2017-04-09','2017-04-16','2017-04-23','2017-04-30','2017-05-07','2017-05-14','2017-05-21','2017-05-28','2017-06-04','2017-06-11','2017-06-18','2017-06-25','2017-07-02','2017-07-09','2017-07-16','2017-07-23','2017-07-30','2017-08-06','2017-08-13','2017-08-20','2017-08-27','2017-09-03','2017-09-10','2017-09-17','2017-09-24','2017-10-01','2017-10-08','2017-10-15','2017-10-22','2017-10-29','2017-11-05','2017-11-12','2017-11-19','2017-11-26','2017-12-03','2017-12-10','2017-12-17','2017-12-24','2017-12-31','2018-01-07','2018-01-14','2018-01-21','2018-01-28','2018-02-04','2018-02-11','2018-02-18','2018-02-
        words_final=pd.concat([words_final,csv], ignore_index=True)
    except:
        pass

# %%
words_final
# Out:
#                                product_category_name 2016-02-21 2016-02-28  \
# 0                          eletroportateis: (Brasil)          0         15
# 1                         eletrodomesticos: (Brasil)         18         26
# 2                              eletronicos: (Brasil)         78         65
# 3                      moveis e escritorio: (Brasil)         68         50
# 4                         telefonia e fixa: (Brasil)          0          0
# 5                     ferramentas e jardim: (Brasil)          0          0
# 6                           market e place: (Brasil)          0          0
# 7                                    audio: (Brasil)         67         59
# 8                         consoles e games: (Brasil)         97          0
# 9    construcao e ferramentas e construcao: (Brasil)          0          0
# 10                               papelaria: (Brasil)         45         38
# ...

# %%
words_final.product_category_name = words_final['product_category_name'].str.split(':').str[0].str.replace(' e ','_')

# %%
words_final = words_final.T

# %%
words_final
# Out:
#                  product_category_name 2016-02-21 2016-02-28 2016-03-06  \
# 0                      eletroportateis          0         15         47
# 1                     eletrodomesticos         18         26         27
# 2                          eletronicos         78         65         77
# 3                    moveis_escritorio         68         50         68
# 4                       telefonia_fixa          0          0         19
# 5                   ferramentas_jardim          0          0          0
# 6                         market_place          0          0         21
# 7                                audio         67         59         63
# 8                       consoles_games         97          0          0
# 9    construcao_ferramentas_construcao          0          0          0
# 10                           papelaria         45         38         35
# 11                            pet_shop         67         47         48
# ...

# %%
for i in words_final.columns:
    ##deep copy = faz a copia real do dataframe, ao invez de dar um novo endereço
    df = words_final[[i]].copy()
    df.columns=['valor']
    df['product_category_name'] = words_final.product_category_name
    df['data']=i

# %%
df
# Out:
#    valor               product_category_name        data
# 0      0                     eletroportateis  2021-02-07
# 1      9                    eletrodomesticos  2021-02-07
# 2     56                         eletronicos  2021-02-07
# 3     44                   moveis_escritorio  2021-02-07
# 4      0                      telefonia_fixa  2021-02-07
# 5     44                  ferramentas_jardim  2021-02-07
# 6      0                        market_place  2021-02-07
# 7     49                               audio  2021-02-07
# 8      0                      consoles_games  2021-02-07
# 9      0   construcao_ferramentas_construcao  2021-02-07
# 10    61                           papelaria  2021-02-07
# 11    62                            pet_shop  2021-02-07
# 12     0  construcao_ferramentas_ferramentas  2021-02-07
# 13    52                              flores  2021-02-07
# 14    28           agro_industria_e_comercio  2021-02-07
# ...

# %%
df.to_sql(name='words', con=conn, if_exists='replace', index=False)

# %% [markdown]
# # doing some analysis

# %% [markdown]
# ## cleaning the data

# %% [markdown]
# ## some standarlization

# %%
# good way to Standardize

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X) # aprende a media e a variancia do seu X

# %%
scaler.transform(X)

# %%
X_std = scaler.transform(X) # aplica a padronização baseada no mean e std que ele aprendeu no fit
X_std

# %% [markdown]
# ## linear regressio

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model1.fit(X,y)

# %%
X = df[['TV']]
y = df['Sales']

# %%
data_to_predict = pd.DataFrame([100, 150, 200, 250, 300, 350, 400, 450], columns=['TV'])
data_to_predict

# %%
sns.regplot(X, y)
plt.xlabel('Years of Education')
plt.ylabel('Money')

plt.hlines(y.mean(),4,14)

# %%
X=pd.get_dummies(df[['years_of_education','gender']], drop_first=True)

# %%
model.fit(X, y)

# %%
pd.concat([X, y], axis=1).corr()

# %% [markdown]
# ## predicting in graph

# %%
X_to_predict = data_to_predict
y_predicted = model.predict(X_to_predict)

# %%
plt.figure(figsize=(8,6))
plt.xlabel('TV')
plt.ylabel('Sales')
plt.scatter(X, y, color='red', label='observed')

# plot the predicted values together with the observed values
plt.scatter(X_all, y_predicted_all, label='predicted')


plt.legend();

# %%
y_pred=model.predict(X)

# %%
plt.figure(figsize=(8,6))
plt.xlabel('TV')
plt.ylabel('Sales')
plt.scatter(X, y, color='red', label='observed')

# plot the predicted values together with the observed values
plt.scatter(X, y_pred, label='predicted')


plt.legend();

# %% [markdown]
# ## calculating the error

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_observed, y_predicted)

# %%
from sklearn.metrics import r2_score

# %%
model.score(X, y)

# %%
# the mean error I would have in sales is:
np.sqrt(mean_squared_error(y_observed, model.predict(X_std)))

# %% [markdown]
# ## model of the score

# %% [markdown]
# # Retrieving the outliers

# %%
lr_no_outlier = LinearRegression()
lr_no_outlier.fit(X, y)

# %%
# Make predictions
predicted_values_no_outlier = lr_no_outlier.predict(X)

print(f'Barrels08= {lr_no_outlier.intercept_:.2f} + {lr_no_outlier.coef_[0]:.2f} * cylinders')

# %%
import matplotlib.pyplot as plt

# Plot outputs
plt.scatter(X, y,  color='k', s=5)
plt.plot(X, predicted_values_no_outlier, color='blue', linewidth=2)

plt.xlabel('Cylinders')
plt.ylabel('barrels08')
plt.grid()
plt.show()

# %% [markdown]
# ## with outliers

# %%
y.iloc[2] = 2000

# Plot variables
plt.scatter(X, y,  color='k', s=5)
plt.scatter(X.iloc[2], y.iloc[2], color='red', marker='s')

plt.xlabel('Cylinders')
plt.ylabel('barrels08')

plt.grid()
plt.show()

# %%
# Perform Linear Regression
lr = LinearRegression()
lr.fit(X, y)

# Make predictions
predicted_values_outliers = lr.predict(X)

# %%
# Plot outputs
plt.scatter(X, y,  color='k', s=5)
plt.scatter(X.iloc[2], y.iloc[2], color='red', marker='s')

plt.plot(X, predicted_values_no_outlier , color='blue', linewidth=2)
plt.plot(X, predicted_values_outliers, color='red', linewidth=2)


plt.xlabel('Cylinders')
plt.ylabel('barrels08')

plt.ylim([5, 35])
plt.grid()
plt.legend(['NO Outlier','WITH Outlier'])
plt.show()

print(f'Equação: {lr_no_outlier.intercept_:.2f} + {lr_no_outlier.coef_[0]:.2f} * cylinders')
print(f'Equação: {lr.intercept_:.2f} + {lr.coef_[0]:.2f} * cylinders')
