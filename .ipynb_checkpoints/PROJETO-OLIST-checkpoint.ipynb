# %%
import sqlalchemy as db
import os
from selenium.webdriver.common.by import By
from selenium import webdriver
import unittest
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.common.exceptions import TimeoutException
from multiprocess import Pool
import selenium
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import pandas as pd
from selenium import webdriver
from PIL import Image
from io import BytesIO
from bs4 import BeautifulSoup
import tqdm
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
engine = db.create_engine('postgresql://postgres:admin@localhost/olist')
# localhost = 127.0.0.1
# open the connection
conn = engine.connect()

# %%
os.listdir('archive')[0]
# Out:
# 'olist_sellers_dataset.csv'

# %%
os.listdir('csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-6e8d08caecc6> in <module>
# ----> 1 os.listdir('csv')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'csv'

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/Users/usuario/Desktop/olist'

# %%
for f in os.listdir('archive'):
    x = pd.read_csv(f'archive/{f}',low_memory=False)
    x.to_sql(name=f.replace('.csv',''), con=conn, if_exists='replace', index=False)

# %%
chrome_path = '/Users/usuario/Desktop/ironhack/18 - api wrappers/chromedriver'
url = 'https://trends.google.com.br/trends'

# %%
import psycopg2
from psycopg2 import OperationalError
def execute_read_query(conn, query):
    cursor = conn.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except OperationalError as e:
        print(f"The error '{e}' occurred")

# %%
rows = pd.read_sql_query('SELECT product_category_name FROM product_category_name_translation;', con=conn)

# %%
rows = rows.T

# %%
rows = list(rows)

# %%
for r in rows:
    print('oi')
# Out:
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi

# %%
rows
# Out:
#                                  0                       1           2   \
# product_category_name  beleza_saude  informatica_acessorios  automotivo
#
#                                     3                 4              5   \
# product_category_name  cama_mesa_banho  moveis_decoracao  esporte_lazer
#
#                                6                      7          8   \
# product_category_name  perfumaria  utilidades_domesticas  telefonia
#
#                                        9   ...      61               62  \
# product_category_name  relogios_presentes  ...  musica  casa_conforto_2
#
#                                                 63                 64  \
# product_category_name  portateis_casa_forno_e_cafe  cds_dvds_musicais
#
#                                  65      66                  67  \
# product_category_name  dvds_blu_ray  flores  artes_e_artesanato
#
#                                     68                             69  \
# product_category_name  fraldas_higiene  fashion_roupa_infanto_juvenil
#
#                                        70
# product_category_name  seguros_e_servicos
#
# [1 rows x 71 columns]

# %%
pesquisa = ' e '.join(rows[0][::][0].split('_'))

# %%
pesquisa
# Out:
# 'beleza e saude'

# %%
#driver = webdriver.Chrome(executable_path=chrome_path)
#driver = webdriver.Safari()
time.sleep(5)
#driver = webdriver.Chrome(executable_path=chrome_path)
driver = webdriver.Safari()
driver.get(url) 
driver.maximize_window()
driver.get(url) 
df= pd.DataFrame(columns=['resposta'])
for i in range(len(rows)-1):
    pesquisa = ' e '.join(rows[i][0:1][0].split('_'))
    driver.get(url) 
    time.sleep(2.3)
    elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/ng-include/div/div[2]/autocomplete/md-autocomplete/md-autocomplete-wrap/input')
    elem.send_keys(pesquisa)
    elem.send_keys(Keys.RETURN)
    time.sleep(2.5)
    elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/header/div/div[3]/ng-transclude/div[2]/div/div/custom-date-picker/ng-include/md-select/md-select-value/span[2]')     
    elem.click()
    time.sleep(1)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    elem.send_keys(Keys.DOWN)
    
    elem.send_keys(Keys.RETURN)
    
    time.sleep(1.5)
    try:
        elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[1]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]')
        elem.click()
        time.sleep(2.5)
        elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[2]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]/i')
        elem.click()
        time.sleep(2)
        try:
            resposta = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[4]/trends-widget/ng-include/widget/div/div/ng-include/div/div[1]/div/ng-include/a/div/div[2]/span').text
            df = pd.DataFrame([resposta])
            df.columns=['resposta']
            
        except:
            pass
    except:
        pass

# %%
time.sleep(5)
#driver = webdriver.Chrome(executable_path=chrome_path)
driver = webdriver.Safari()
driver.get(url) 
driver.maximize_window()
driver.get(url) 
df= pd.DataFrame(columns=['resposta'])
pesquisa = ' e '.join(rows[i][0:1][0].split('_'))
pesquisa
driver.get(url) 
time.sleep(2.3)
elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/ng-include/div/div[2]/autocomplete/md-autocomplete/md-autocomplete-wrap/input')
elem.send_keys(pesquisa)
elem.send_keys(Keys.RETURN)
time.sleep(2.5)
elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/header/div/div[3]/ng-transclude/div[2]/div/div/custom-date-picker/ng-include/md-select/md-select-value/span[2]')     
elem.click()
time.sleep(1)
elem.send_keys(Keys.DOWN)
elem.send_keys(Keys.DOWN)
elem.send_keys(Keys.DOWN)
elem.send_keys(Keys.DOWN)
elem.send_keys(Keys.DOWN)
elem.send_keys(Keys.DOWN)
elem.send_keys(Keys.DOWN)

elem.send_keys(Keys.RETURN)

time.sleep(1.5)

elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[1]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]')
elem.click()
time.sleep(2.5)
elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[2]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]/i')
elem.click()
time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-198-6fa909791841> in <module>
#       6 driver.get(url)
#       7 df= pd.DataFrame(columns=['resposta'])
# ----> 8 pesquisa = ' e '.join(rows[i][0:1][0].split('_'))
#       9 pesquisa
#      10 driver.get(url)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     356                 except ValueError as err:
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#     360
#
# KeyError: 'climatizacao'

# %%
#driver = webdriver.Safari()
    driver.get(url) 
    time.sleep(2.3)
    elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/ng-include/div/div[2]/autocomplete/md-autocomplete/md-autocomplete-wrap/input')
    elem.send_keys(pesquisa)
    elem.send_keys(Keys.RETURN)
    time.sleep(2)
    elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[1]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]')
    elem.click()
    time.sleep(2)
    elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[2]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]/i')
    elem.click()
    time.sleep(2)
    resposta = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[4]/trends-widget/ng-include/widget/div/div/ng-include/div/div[1]/div/ng-include/a/div/div[2]/span').text
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-4-3a058edc0267> in <module>
#       3 driver.get(url)
#       4 time.sleep(5)
# ----> 5 elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/ng-include/div/div[2]/autocomplete/md-autocomplete/md-autocomplete-wrap/input')
#       6 elem.send_keys('Iphone')
#       7 elem.send_keys(Keys.RETURN)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[2]/div[2]/div/ng-include/div/div[2]/autocomplete/md-autocomplete/md-autocomplete-wrap/input"}
#   (Session info: chrome=88.0.4324.150)

# %%
import os

# %%
diretorio = '/Users/usuario/Downloads/multiTimeline-12.csv'

# %%
lista1 = pd.read_csv(diretorio)

# %%
lista1.T
# Out:
#                                                        Semana 2016-02-21  \
# Categoria: Todas as categorias  cama e mesa e banho: (Brasil)         35
#
#                                2016-02-28 2016-03-06 2016-03-13 2016-03-20  \
# Categoria: Todas as categorias         53         59         43         39
#
#                                2016-03-27 2016-04-03 2016-04-10 2016-04-17  \
# Categoria: Todas as categorias         45         30         57         45
#
#                                 ... 2020-12-06 2020-12-13 2020-12-20  \
# Categoria: Todas as categorias  ...         63         43         25
#
#                                2020-12-27 2021-01-03 2021-01-10 2021-01-17  \
# Categoria: Todas as categorias         37         35         41         35
#
#                                2021-01-24 2021-01-31 2021-02-07
# Categoria: Todas as categorias         38         35         35
#
# [1 rows x 261 columns]

# %%
diretorio1 = '/Users/usuario/Downloads/final_agoravai.csv'

# %%
agoravai = pd.read_csv(diretorio1)

# %%
agoravai.to_sql(name='words', con=conn, if_exists='replace', index=False)

# %%
lista2 = pd.read_csv(diretorio1)

# %%
lista2 = lista2.T

# %%
df_final = pd.DataFrame

# %%
lista2.columns
# Out:
# Index(['Região', 'Mato Grosso do Sul', 'Goiás', 'Santa Catarina', 'Pernambuco',
#        'Bahia', 'Distrito Federal', 'Ceará', 'São Paulo', 'Rio Grande do Sul',
#        'Rio de Janeiro', 'Paraná', 'Minas Gerais', 'Amapá', 'Rondônia',
#        'Piauí', 'Mato Grosso', 'Espírito Santo', 'Pará', 'Paraíba', 'Sergipe',
#        'Maranhão', 'Alagoas', 'Amazonas', 'Acre', 'Rio Grande do Norte',
#        'Roraima', 'Tocantins'],
#       dtype='object')

# %%
lista2.columns = ['product_category_name', 'Mato Grosso do Sul', 'Goiás', 'Santa Catarina', 'Pernambuco',
       'Bahia', 'Distrito Federal', 'Ceará', 'São Paulo', 'Rio Grande do Sul',
       'Rio de Janeiro', 'Paraná', 'Minas Gerais', 'Amapá', 'Rondônia',
       'Piauí', 'Mato Grosso', 'Espírito Santo', 'Pará', 'Paraíba', 'Sergipe',
       'Maranhão', 'Alagoas', 'Amazonas', 'Acre', 'Rio Grande do Norte',
       'Roraima', 'Tocantins']

# %%
datageo = pd.DataFrame(columns=['product_category_name', 'Mato Grosso do Sul', 'Goiás', 'Santa Catarina', 'Pernambuco',
       'Bahia', 'Distrito Federal', 'Ceará', 'São Paulo', 'Rio Grande do Sul',
       'Rio de Janeiro', 'Paraná', 'Minas Gerais', 'Amapá', 'Rondônia',
       'Piauí', 'Mato Grosso', 'Espírito Santo', 'Pará', 'Paraíba', 'Sergipe',
       'Maranhão', 'Alagoas', 'Amazonas', 'Acre', 'Rio Grande do Norte',
       'Roraima', 'Tocantins'])

# %%
os.listdir('/Users/usuario/Downloads')
# Out:
# ['geoMap-16.csv',
#  'multiTimeline-7.csv',
#  'multiTimeline-23.csv',
#  'geoMap-2.csv',
#  'multiTimeline-37.csv',
#  'geoMap (3).csv',
#  'multiTimeline.csv',
#  'multiTimeline-36.csv',
#  'multiTimeline-22.csv',
#  'geoMap-3.csv',
#  'multiTimeline-6.csv',
#  'geoMap-17.csv',
#  'geoMap-15.csv',
#  'geoMap-29.csv',
#  'multiTimeline-4.csv',
#  'Telegram Desktop',
#  'Notion-2.0.11.dmg',
#  'O que é Voar Sem Asas Online 2.mp4',
#  'multiTimeline-34.csv',
#  'multiTimeline-20.csv',
#  'Proposta Comercial sem Integração - Nupik.pdf',
#  'multiTimeline-21.csv',
#  'multiTimeline-35.csv',
#  'berka.pdf',
#  'multiTimeline-5.csv',
#  'geoMap-28.csv',
#  'geoMap-14.csv',
#  'geoMap-38.csv',
#  'geoMap-10.csv',
#  'multiTimeline-19.csv',
#  'multiTimeline-31.csv',
#  'multiTimeline-25.csv',
#  'geoMap-4.csv',
#  'dia 10',
#  '.DS_Store',
#  'multiTimeline-24.csv',
#  'geoMap-5.csv',
#  'multiTimeline-30.csv',
#  'multiTimeline-18.csv',
#  'geoMap-11.csv',
#  'mh8jrcwis8jhaz3itvj7x1zw4xpn55.html',
#  'geoMap-39.csv',
#  'geoMap-13.csv',
#  'multiTimeline-2.csv',
#  'geoMap-7.csv',
#  'multiTimeline-26.csv',
#  'multiTimeline-32.csv',
#  'Agenda do Canal.png',
#  'geoMap (2).csv',
#  'COLAGEM - Celular.png',
#  'multiTimeline-33.csv',
#  'geoMap-6.csv',
#  'Aula de pilotagem_Novo.pptx',
#  'multiTimeline-27.csv',
#  '.localized',
#  'multiTimeline-3.csv',
#  'geoMap-12.csv',
#  'geoMap-61.csv',
#  'geoMap-49.csv',
#  'multiTimeline-40.csv',
#  'multiTimeline-54.csv',
#  'multiTimeline-68.csv',
#  'multiTimeline-69.csv',
#  'multiTimeline-55.csv',
#  'multiTimeline-41.csv',
#  'geoMap-48.csv',
#  'geoMap-60.csv',
#  'geoMap-62.csv',
#  'EquiSync-Demo-V5.mp3',
#  'multiTimeline-57.csv',
#  'multiTimeline-43.csv',
#  'Promo 1.mp4',
#  'multiTimeline-42.csv',
#  'multiTimeline-56.csv',
#  'EMENTA DO CURSO DE PILOTAGEM_.pdf',
#  'geoMap-63.csv',
#  'Novas Inscrições 2.png',
#  'geoMap-67.csv',
#  'dia 7',
#  'multiTimeline-52.csv',
#  'multiTimeline-46.csv',
#  'geoMap (4).csv',
#  'dia 9',
#  'SWTM-2088_Atlassian-Git-Cheatsheet.pdf',
#  'multiTimeline-47.csv',
#  'multiTimeline-53.csv',
#  'multiTimeline (1).csv',
#  'geoMap-66.csv',
#  'geoMap-58.csv',
#  'geoMap-64.csv',
#  'dia 8',
#  'multiTimeline-45.csv',
#  'multiTimeline-51.csv',
#  'multiTimeline-50.csv',
#  'multiTimeline-44.csv',
#  'geoMap-65.csv',
#  'geoMap-59.csv',
#  'geoMap-40.csv',
#  'geoMap-54.csv',
#  'geoMap-68.csv',
#  'multiTimeline-61.csv',
#  'multiTimeline-49.csv',
#  'Captura de Tela 2021-01-29 às 19.15.41.png',
#  'multiTimeline-48.csv',
#  'multiTimeline-60.csv',
#  'Carrousel---Lançamento---O-que-Voar-Sem-Asas-online_01.png',
#  'geoMap-69.csv',
#  'geoMap-55.csv',
#  'geoMap-41.csv',
#  'geoMap-57.csv',
#  'geoMap-43.csv',
#  'Carrousel---Lançamento---O-que-Voar-Sem-Asas-online_03.png',
#  'multiTimeline-62.csv',
#  'multiprocessing.ipynb',
#  'financial.sql',
#  'multiTimeline-63.csv',
#  'multiTimeline (2).csv',
#  'Carrousel---Lançamento---O-que-Voar-Sem-Asas-online_02.png',
#  'geoMap-42.csv',
#  'geoMap-56.csv',
#  'geoMap-52.csv',
#  'geoMap-46.csv',
#  'Carrousel---Lançamento---O-que-Voar-Sem-Asas-online_06.png',
#  'Relatório de Análise .xlsx',
#  'multiTimeline-73.csv',
#  'multiTimeline (3).csv',
#  'multiTimeline-67.csv',
#  'Segunda Turma 3.png',
#  'Segunda Turma 2.png',
#  'multiTimeline-66.csv',
#  'multiTimeline-72.csv',
#  'Cisco_WebEx_Add-On.dmg',
#  'geoMap-47.csv',
#  'geoMap-53.csv',
#  'geoMap.csv',
#  'geoMap-45.csv',
#  'geoMap-51.csv',
#  'Carrousel---Lançamento---O-que-Voar-Sem-Asas-online_05.png',
#  'multiTimeline-58.csv',
#  'multiTimeline-64.csv',
#  'multiTimeline-70.csv',
#  'Vem Pro Telegram.png',
#  'Segunda Turma 1.png',
#  'multiTimeline-71.csv',
#  'multiTimeline-65.csv',
#  'multiTimeline-59.csv',
#  'Carrousel---Lançamento---O-que-Voar-Sem-Asas-online_04.png',
#  'geoMap-50.csv',
#  'geoMap-44.csv',
#  'geoMap-23.csv',
#  'geoMap-37.csv',
#  '.ipynb_checkpoints',
#  'multiTimeline-16.csv',
#  'geoMap (1).csv',
#  'iTerm.app',
#  'multiTimeline-17.csv',
#  'multiTimeline (4).csv',
#  'Holograma Arcturianos - FOCO.jpg',
#  'geoMap-36.csv',
#  'geoMap-22.csv',
#  'geoMap-34.csv',
#  'geoMap-20.csv',
#  'multiTimeline-15.csv',
#  'multiTimeline-29.csv',
#  'geoMap-8.csv',
#  'Checklist Escopo Nupik - Checklist - .pdf',
#  'multiTimeline-28.csv',
#  'geoMap-9.csv',
#  'multiTimeline-14.csv',
#  'Como_escrever_uma_página_de_vendas.pdf',
#  'geoMap-21.csv',
#  'geoMap-35.csv',
#  'geoMap-19.csv',
#  'geoMap-31.csv',
#  'geoMap-25.csv',
#  'multiTimeline-8.csv',
#  'multiTimeline-38.csv',
#  'multiTimeline-10.csv',
#  'multiTimeline-11.csv',
#  'multiTimeline-39.csv',
#  'multiTimeline-9.csv',
#  'geoMap-24.csv',
#  'geoMap-30.csv',
#  'geoMap-18.csv',
#  'geoMap-26.csv',
#  'geoMap-32.csv',
#  'multiTimeline-13.csv',
#  'multiTimeline-12.csv',
#  'geoMap-33.csv',
#  'geoMap-27.csv']

# %% [markdown]
# # jogar para o csv

# %%
geograph = [i for i in os.listdir('/Users/usuario/Downloads') if i.startswith('geoMap-')]

# %%
geograph
# Out:
# ['geoMap-16.csv',
#  'geoMap-17.csv',
#  'geoMap-15.csv',
#  'geoMap-29.csv',
#  'geoMap-28.csv',
#  'geoMap-14.csv',
#  'geoMap-38.csv',
#  'geoMap-10.csv',
#  'geoMap-11.csv',
#  'geoMap-39.csv',
#  'geoMap-13.csv',
#  'geoMap-12.csv',
#  'geoMap-61.csv',
#  'geoMap-49.csv',
#  'geoMap-48.csv',
#  'geoMap-60.csv',
#  'geoMap-62.csv',
#  'geoMap-63.csv',
#  'geoMap-67.csv',
#  'geoMap-66.csv',
#  'geoMap-58.csv',
#  'geoMap-64.csv',
#  'geoMap-65.csv',
#  'geoMap-59.csv',
#  'geoMap-40.csv',
#  'geoMap-54.csv',
#  'geoMap-68.csv',
#  'geoMap-55.csv',
#  'geoMap-41.csv',
#  'geoMap-57.csv',
#  'geoMap-43.csv',
#  'geoMap-42.csv',
#  'geoMap-56.csv',
#  'geoMap-52.csv',
#  'geoMap-46.csv',
#  'geoMap-47.csv',
#  'geoMap-53.csv',
#  'geoMap-45.csv',
#  'geoMap-51.csv',
#  'geoMap-50.csv',
#  'geoMap-44.csv',
#  'geoMap-23.csv',
#  'geoMap-37.csv',
#  'geoMap-36.csv',
#  'geoMap-22.csv',
#  'geoMap-34.csv',
#  'geoMap-20.csv',
#  'geoMap-8.csv',
#  'geoMap-9.csv',
#  'geoMap-21.csv',
#  'geoMap-35.csv',
#  'geoMap-19.csv',
#  'geoMap-31.csv',
#  'geoMap-25.csv',
#  'geoMap-24.csv',
#  'geoMap-30.csv',
#  'geoMap-18.csv',
#  'geoMap-26.csv',
#  'geoMap-32.csv',
#  'geoMap-33.csv',
#  'geoMap-27.csv']

# %%
datageo = pd.DataFrame(columns=['product_category_name', 'Mato Grosso do Sul', 'Goiás', 'Santa Catarina', 'Pernambuco',
   'Bahia', 'Distrito Federal', 'Ceará', 'São Paulo', 'Rio Grande do Sul',
   'Rio de Janeiro', 'Paraná', 'Minas Gerais', 'Amapá', 'Rondônia',
   'Piauí', 'Mato Grosso', 'Espírito Santo', 'Pará', 'Paraíba', 'Sergipe',
   'Maranhão', 'Alagoas', 'Amazonas', 'Acre', 'Rio Grande do Norte',
   'Roraima', 'Tocantins'])
for i in geograph:
    csv = pd.read_csv(f'/Users/usuario/Downloads/{i}')
    csv = csv.T
    csv.columns = ['product_category_name', 'Mato Grosso do Sul', 'Goiás', 'Santa Catarina', 'Pernambuco',
       'Bahia', 'Distrito Federal', 'Ceará', 'São Paulo', 'Rio Grande do Sul',
       'Rio de Janeiro', 'Paraná', 'Minas Gerais', 'Amapá', 'Rondônia',
       'Piauí', 'Mato Grosso', 'Espírito Santo', 'Pará', 'Paraíba', 'Sergipe',
       'Maranhão', 'Alagoas', 'Amazonas', 'Acre', 'Rio Grande do Norte',
       'Roraima', 'Tocantins']
    datageo=pd.concat([datageo,csv], ignore_index=True)

# %%
datageo
# Out:
#                                 product_category_name Mato Grosso do Sul  \
# 0                papelaria: (15/02/2016 – 15/02/2021)                100
# 1   tablets e impressao e imagem: (15/02/2016 – 15...                NaN
# 2      alimentos e bebidas: (15/02/2016 – 15/02/2021)                100
# 3   construcao e ferramentas e jardim: (15/02/2016...                NaN
# 4   construcao e ferramentas e construcao: (15/02/...                NaN
# ..                                                ...                ...
# 56        telefonia e fixa: (15/02/2016 – 15/02/2021)                NaN
# 57      malas e acessorios: (15/02/2016 – 15/02/2021)                NaN
# 58     moveis e escritorio: (15/02/2016 – 15/02/2021)                100
# 59             eletronicos: (15/02/2016 – 15/02/2021)                100
# 60            climatizacao: (15/02/2016 – 15/02/2021)                100
#
#    Goiás Santa Catarina Pernambuco Bahia Distrito Federal Ceará São Paulo  \
# 0     98             96         93    85               82    75        74
# 1    NaN            NaN        NaN   NaN              NaN   NaN       NaN
# 2     97             97         92    90               87    84        81
# 3    NaN            NaN        NaN   NaN              NaN   NaN       NaN
# 4    NaN            NaN        NaN   NaN              NaN   NaN       NaN
# ..   ...            ...        ...   ...              ...   ...       ...
# 56   NaN            NaN        NaN   NaN              NaN   NaN       NaN
# 57   NaN            NaN        NaN   NaN              NaN   NaN       NaN
# 58   100             91        NaN   NaN              NaN   NaN       NaN
# 59    80             70         56    56               48    47        45
# 60    78             41         33    33               32    29        26
#
#    Rio Grande do Sul  ... Pará Paraíba Sergipe Maranhão Alagoas Amazonas Acre  \
# 0                 70  ...   32      31      31       29      29       28   27
# 1                NaN  ...  NaN     NaN     NaN      NaN     NaN      NaN  NaN
# 2                 80  ...   46     NaN     NaN      NaN     NaN      NaN  NaN
# 3                NaN  ...  NaN     NaN     NaN      NaN     NaN      NaN  NaN
# 4                NaN  ...  NaN     NaN     NaN      NaN     NaN      NaN  NaN
# ..               ...  ...  ...     ...     ...      ...     ...      ...  ...
# 56               NaN  ...  NaN     NaN     NaN      NaN     NaN      NaN  NaN
# 57               NaN  ...  NaN     NaN     NaN      NaN     NaN      NaN  NaN
# 58               NaN  ...  NaN     NaN     NaN      NaN     NaN      NaN  NaN
# 59                44  ...   36      35      35       35      34       34   34
# 60                25  ...  NaN     NaN     NaN      NaN     NaN      NaN  NaN
#
#    Rio Grande do Norte Roraima Tocantins
# 0                   24      22        18
# 1                  NaN     NaN       NaN
# 2                  NaN     NaN       NaN
# 3                  NaN     NaN       NaN
# 4                  NaN     NaN       NaN
# ..                 ...     ...       ...
# 56                 NaN     NaN       NaN
# 57                 NaN     NaN       NaN
# 58                 NaN     NaN       NaN
# 59                  33      33        31
# 60                 NaN     NaN       NaN
#
# [61 rows x 28 columns]

# %%
datageo.product_category_name = datageo['product_category_name'].str.split(':').str[0].str.replace(' e ','_')

# %%
datageo = datageo.T

# %%
datageo
# Out:
#                  product_category_name Mato Grosso do Sul Goiás  \
# 0                            papelaria                100    98
# 1             tablets_impressao_imagem                NaN   NaN
# 2                    alimentos_bebidas                100    97
# 3        construcao_ferramentas_jardim                NaN   NaN
# 4    construcao_ferramentas_construcao                NaN   NaN
# 5                utilidades_domesticas                100   NaN
# 6            agro_industria_e_comercio                100   NaN
# 7                           automotivo                100    95
# 8                      cama_mesa_banho                100    78
# 9            moveis_colchao_e_estofado                NaN   NaN
# 10                          perfumaria                100    45
# 11                       esporte_lazer                100    80
# 12                          la_cuisine                NaN   NaN
# 13              livros_interesse_geral                NaN   NaN
# 14                       moveis_quarto                100    83
# 15                           cine_foto                NaN   NaN
# 16         portateis_casa_forno_e_cafe                NaN   NaN
# 17                   cds_dvds_musicais                NaN   NaN
# 18                     fraldas_higiene                NaN   NaN
# 19                  artes_e_artesanato                100   NaN
# 20                   livros_importados                NaN   NaN
# 21                        dvds_blu_ray                NaN   NaN
# 22                              flores                100    81
# 23                             bebidas                100    99
# 24                     livros_tecnicos                NaN   NaN
# 25                                 pcs                100    96
# 26       fashion_roupa_infanto_juvenil                NaN   NaN
# 27                    artigos_de_natal                NaN   NaN
# 28                     casa_construcao                100    23
# 29                  eletrodomesticos_2                NaN   NaN
# 30                         moveis_sala                100    90
# 31               instrumentos_musicais                100    98
# 32              fashion_roupa_feminina                NaN   NaN
# 33                     fashion_esporte                NaN   NaN
# 34                           alimentos                100    99
# 35                               artes                100    73
# 36             sinalizacao_e_seguranca                NaN   NaN
# 37       industria_comercio_e_negocios                NaN   NaN
# 38      fashion_underwear_e_moda_praia                NaN   NaN
# 39    construcao_ferramentas_seguranca                NaN   NaN
# 40   construcao_ferramentas_iluminacao                NaN   NaN
# 41                               audio                100   100
# 42  construcao_ferramentas_ferramentas                NaN   NaN
# 43                       casa_conforto                100    81
# 44                      consoles_games                NaN   NaN
# 45                    eletrodomesticos                100    85
# 46         fashion_bolsas_e_acessorios                NaN   NaN
# 47                        beleza_saude                100    62
# 48              informatica_acessorios                100   NaN
# 49                     eletroportateis                100    80
# 50                   artigos_de_festas                100   NaN
# 51                  ferramentas_jardim                NaN   NaN
# 52                            pet_shop                100    99
# 53                          cool_stuff                NaN   NaN
# 54                    fashion_calcados                NaN   NaN
# 55             fashion_roupa_masculina                NaN   NaN
# 56                      telefonia_fixa                NaN   NaN
# 57                    malas_acessorios                NaN   NaN
# 58                   moveis_escritorio                100   100
# 59                         eletronicos                100    80
# 60                        climatizacao                100    78
#
#    Santa Catarina Pernambuco Bahia Distrito Federal Ceará São Paulo  \
# 0              96         93    85               82    75        74
# 1             NaN        NaN   NaN              NaN   NaN       NaN
# 2              97         92    90               87    84        81
# 3             NaN        NaN   NaN              NaN   NaN       NaN
# 4             NaN        NaN   NaN              NaN   NaN       NaN
# 5             NaN        NaN   NaN              NaN   NaN       NaN
# 6             NaN        NaN   NaN              NaN   NaN       NaN
# 7              93         85    83               83    80        80
# 8              73         73    68               65    63        63
# 9             NaN        NaN   NaN              NaN   NaN       NaN
# 10             40         40    36               33    27        26
# 11             78         76    72               69    67        64
# 12            NaN        NaN   NaN              NaN   NaN       NaN
# 13            NaN        NaN   NaN              NaN   NaN       NaN
# 14             79        NaN   NaN              NaN   NaN       NaN
# 15            NaN        NaN   NaN              NaN   NaN       NaN
# 16            NaN        NaN   NaN              NaN   NaN       NaN
# 17            NaN        NaN   NaN              NaN   NaN       NaN
# 18            NaN        NaN   NaN              NaN   NaN       NaN
# 19            NaN        NaN   NaN              NaN   NaN       NaN
# 20            NaN        NaN   NaN              NaN   NaN       NaN
# 21            NaN        NaN   NaN              NaN   NaN       NaN
# 22             80         74    73               73    71        71
# 23             94         88    82               81    76        76
# 24            NaN        NaN   NaN              NaN   NaN       NaN
# 25             78         77    74               73    73        72
# 26            NaN        NaN   NaN              NaN   NaN       NaN
# 27            NaN        NaN   NaN              NaN   NaN       NaN
# 28             22         19    11               11     9         8
# 29            NaN        NaN   NaN              NaN   NaN       NaN
# 30             85         83    80              NaN   NaN       NaN
# 31             89         84    83               80    78        75
# 32            NaN        NaN   NaN              NaN   NaN       NaN
# 33            NaN        NaN   NaN              NaN   NaN       NaN
# 34             97         97    96               95    93        92
# 35             67         65    63               63    61        60
# 36            NaN        NaN   NaN              NaN   NaN       NaN
# 37            NaN        NaN   NaN              NaN   NaN       NaN
# 38            NaN        NaN   NaN              NaN   NaN       NaN
# 39            NaN        NaN   NaN              NaN   NaN       NaN
# 40            NaN        NaN   NaN              NaN   NaN       NaN
# 41             96         95    95               95    95        94
# 42            NaN        NaN   NaN              NaN   NaN       NaN
# 43             61         44    41               34    31        29
# 44            NaN        NaN   NaN              NaN   NaN       NaN
# 45             80         77    76               73    72        68
# 46            NaN        NaN   NaN              NaN   NaN       NaN
# 47             44         42    41               41    38        36
# 48            NaN        NaN   NaN              NaN   NaN       NaN
# 49             69         68    65               61    60        60
# 50            NaN        NaN   NaN              NaN   NaN       NaN
# 51            NaN        NaN   NaN              NaN   NaN       NaN
# 52             95         92    90               90    80        77
# 53            NaN        NaN   NaN              NaN   NaN       NaN
# 54            NaN        NaN   NaN              NaN   NaN       NaN
# 55            NaN        NaN   NaN              NaN   NaN       NaN
# 56            NaN        NaN   NaN              NaN   NaN       NaN
# 57            NaN        NaN   NaN              NaN   NaN       NaN
# 58             91        NaN   NaN              NaN   NaN       NaN
# 59             70         56    56               48    47        45
# 60             41         33    33               32    29        26
#
#    Rio Grande do Sul Rio de Janeiro Paraná Minas Gerais Amapá Rondônia Piauí  \
# 0                 70             69     65           65    54       54    41
# 1                NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 2                 80             78     76           70    68       67    65
# 3                NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 4                NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 5                NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 6                NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 7                 79             76     74           73    72       70    70
# 8                 63             62     62           60    58       55    55
# 9                NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 10                25             24     24           23    22       21    20
# 11                62             62     61           60    58       56    54
# 12               NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 13               NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 14               NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 15               NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 16               NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 17               NaN            NaN    NaN          NaN   NaN      NaN   NaN
# 18               NaN            NaN    NaN          NaN   NaN      NaN   NaN
#
# 26  NaN                 NaN     NaN       NaN
# 27  NaN                 NaN     NaN       NaN
# 28  NaN                 NaN     NaN       NaN
# 29  NaN                 NaN     NaN       NaN
# 30  NaN                 NaN     NaN       NaN
# 31  NaN                 NaN     NaN       NaN
# 32  NaN                 NaN     NaN       NaN
# 33  NaN                 NaN     NaN       NaN
# 34   78                  76      76        75
# 35   49                  49      46        41
# 36  NaN                 NaN     NaN       NaN
# 37  NaN                 NaN     NaN       NaN
# 38  NaN                 NaN     NaN       NaN
# 39  NaN                 NaN     NaN       NaN
# 40  NaN                 NaN     NaN       NaN
# 41   84                  83      82        80
# 42  NaN                 NaN     NaN       NaN
# 43  NaN                 NaN     NaN       NaN
# 44  NaN                 NaN     NaN       NaN
# 45   46                  43      40        33
# 46  NaN                 NaN     NaN       NaN
# 47  NaN                 NaN     NaN       NaN
# 48  NaN                 NaN     NaN       NaN
# 49  NaN                 NaN     NaN       NaN
# 50  NaN                 NaN     NaN       NaN
# 51  NaN                 NaN     NaN       NaN
# 52  NaN                 NaN     NaN       NaN
# 53  NaN                 NaN     NaN       NaN
# 54  NaN                 NaN     NaN       NaN
# 55  NaN                 NaN     NaN       NaN
# 56  NaN                 NaN     NaN       NaN
# 57  NaN                 NaN     NaN       NaN
# 58  NaN                 NaN     NaN       NaN
# 59   34                  33      33        31
# 60  NaN                 NaN     NaN       NaN

# %%
engine = db.create_engine('postgresql://postgres:admin@localhost/olist')
# localhost = 127.0.0.1
# open the connection
conn = engine.connect()

# %%
datageo.to_sql(name='datageo', con=conn, if_exists='replace', index=False)

# %%
from multiprocessing import Pool, cpu_count

cpu_count()
# Out:
# 4

# %%
pool = Pool(4)

# %%
words = [i for i in os.listdir('/Users/usuario/Downloads') if i.startswith('multiTimeline-')]

# %%
words
# Out:
# ['multiTimeline-23.csv',
#  'multiTimeline-37.csv',
#  'multiTimeline-36.csv',
#  'multiTimeline-22.csv',
#  'multiTimeline-34.csv',
#  'multiTimeline-20.csv',
#  'multiTimeline-21.csv',
#  'multiTimeline-35.csv',
#  'multiTimeline-19.csv',
#  'multiTimeline-31.csv',
#  'multiTimeline-25.csv',
#  'multiTimeline-24.csv',
#  'multiTimeline-30.csv',
#  'multiTimeline-18.csv',
#  'multiTimeline-26.csv',
#  'multiTimeline-32.csv',
#  'multiTimeline-33.csv',
#  'multiTimeline-27.csv',
#  'multiTimeline-40.csv',
#  'multiTimeline-54.csv',
#  'multiTimeline-68.csv',
#  'multiTimeline-69.csv',
#  'multiTimeline-55.csv',
#  'multiTimeline-41.csv',
#  'multiTimeline-57.csv',
#  'multiTimeline-43.csv',
#  'multiTimeline-42.csv',
#  'multiTimeline-56.csv',
#  'multiTimeline-52.csv',
#  'multiTimeline-46.csv',
#  'multiTimeline-47.csv',
#  'multiTimeline-53.csv',
#  'multiTimeline-45.csv',
#  'multiTimeline-51.csv',
#  'multiTimeline-50.csv',
#  'multiTimeline-44.csv',
#  'multiTimeline-61.csv',
#  'multiTimeline-49.csv',
#  'multiTimeline-48.csv',
#  'multiTimeline-60.csv',
#  'multiTimeline-62.csv',
#  'multiTimeline-63.csv',
#  'multiTimeline-67.csv',
#  'multiTimeline-66.csv',
#  'multiTimeline-72.csv',
#  'multiTimeline-58.csv',
#  'multiTimeline-64.csv',
#  'multiTimeline-70.csv',
#  'multiTimeline-71.csv',
#  'multiTimeline-65.csv',
#  'multiTimeline-59.csv',
#  'multiTimeline-16.csv',
#  'multiTimeline-17.csv',
#  'multiTimeline-15.csv',
#  'multiTimeline-29.csv',
#  'multiTimeline-28.csv',
#  'multiTimeline-14.csv',
#  'multiTimeline-38.csv',
#  'multiTimeline-10.csv',
#  'multiTimeline-11.csv',
#  'multiTimeline-39.csv',
#  'multiTimeline-9.csv',
#  'multiTimeline-13.csv',
#  'multiTimeline-12.csv']

# %%
datageo = pd.DataFrame(columns=['product_category_name', 'Mato Grosso do Sul', 'Goiás', 'Santa Catarina', 'Pernambuco',
   'Bahia', 'Distrito Federal', 'Ceará', 'São Paulo', 'Rio Grande do Sul',
   'Rio de Janeiro', 'Paraná', 'Minas Gerais', 'Amapá', 'Rondônia',
   'Piauí', 'Mato Grosso', 'Espírito Santo', 'Pará', 'Paraíba', 'Sergipe',
   'Maranhão', 'Alagoas', 'Amazonas', 'Acre', 'Rio Grande do Norte',
   'Roraima', 'Tocantins'])
for i in geograph:
    csv = pd.read_csv(f'/Users/usuario/Downloads/{i}')
    csv = csv.T
    csv.columns = ['product_category_name', 'Mato Grosso do Sul', 'Goiás', 'Santa Catarina', 'Pernambuco',
       'Bahia', 'Distrito Federal', 'Ceará', 'São Paulo', 'Rio Grande do Sul',
       'Rio de Janeiro', 'Paraná', 'Minas Gerais', 'Amapá', 'Rondônia',
       'Piauí', 'Mato Grosso', 'Espírito Santo', 'Pará', 'Paraíba', 'Sergipe',
       'Maranhão', 'Alagoas', 'Amazonas', 'Acre', 'Rio Grande do Norte',
       'Roraima', 'Tocantins']
    datageo=pd.concat([datageo,csv], ignore_index=True)

# %%
diretorio1 = '/Users/usuario/Downloads/multiTimeline-33.csv'

# %%
words2 = pd.read_csv(diretorio1)

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

pd.set_option('display.max_columns', None)
print(words2.columns)
# Out:
# Index(['Categoria: Todas as categorias'], dtype='object')

# %%
lista = []
for col in words2.columns: 
    print(f"'{col}',")
# Out:
# 'Categoria: Todas as categorias',

# %%
words2 = words2.T

# %%
palavra = [i for i in os.listdir('/Users/usuario/Downloads') if i.startswith('multiTimeline')]

# %%
palavra
# Out:
# ['multiTimeline-23.csv',
#  'multiTimeline-37.csv',
#  'multiTimeline-36.csv',
#  'multiTimeline-22.csv',
#  'multiTimeline-34.csv',
#  'multiTimeline-20.csv',
#  'multiTimeline-21.csv',
#  'multiTimeline-35.csv',
#  'multiTimeline-19.csv',
#  'multiTimeline-31.csv',
#  'multiTimeline-25.csv',
#  'multiTimeline-24.csv',
#  'multiTimeline-30.csv',
#  'multiTimeline-18.csv',
#  'multiTimeline-26.csv',
#  'multiTimeline-32.csv',
#  'multiTimeline-33.csv',
#  'multiTimeline-27.csv',
#  'multiTimeline-40.csv',
#  'multiTimeline-54.csv',
#  'multiTimeline-68.csv',
#  'multiTimeline-69.csv',
#  'multiTimeline-55.csv',
#  'multiTimeline-41.csv',
#  'multiTimeline-57.csv',
#  'multiTimeline-43.csv',
#  'multiTimeline-42.csv',
#  'multiTimeline-56.csv',
#  'multiTimeline-52.csv',
#  'multiTimeline-46.csv',
#  'multiTimeline-47.csv',
#  'multiTimeline-53.csv',
#  'multiTimeline-45.csv',
#  'multiTimeline-51.csv',
#  'multiTimeline-50.csv',
#  'multiTimeline-44.csv',
#  'multiTimeline-61.csv',
#  'multiTimeline-49.csv',
#  'multiTimeline-48.csv',
#  'multiTimeline-60.csv',
#  'multiTimeline-62.csv',
#  'multiTimeline-63.csv',
#  'multiTimeline-67.csv',
#  'multiTimeline-66.csv',
#  'multiTimeline-72.csv',
#  'multiTimeline-58.csv',
#  'multiTimeline-64.csv',
#  'multiTimeline-70.csv',
#  'multiTimeline-71.csv',
#  'multiTimeline-65.csv',
#  'multiTimeline-59.csv',
#  'multiTimeline-16.csv',
#  'multiTimeline-17.csv',
#  'multiTimeline-15.csv',
#  'multiTimeline-29.csv',
#  'multiTimeline-28.csv',
#  'multiTimeline-14.csv',
#  'multiTimeline-38.csv',
#  'multiTimeline-10.csv',
#  'multiTimeline-11.csv',
#  'multiTimeline-39.csv',
#  'multiTimeline-9.csv',
#  'multiTimeline-13.csv',
#  'multiTimeline-12.csv']

# %%
for i in palavra:
    csv = pd.read_csv(f'/Users/usuario/Downloads/{i}')

# %%
csv.T.columns
# Out:
# Index(['Semana', '2016-02-21', '2016-02-28', '2016-03-06', '2016-03-13',
#        '2016-03-20', '2016-03-27', '2016-04-03', '2016-04-10', '2016-04-17',
#        ...
#        '2020-12-06', '2020-12-13', '2020-12-20', '2020-12-27', '2021-01-03',
#        '2021-01-10', '2021-01-17', '2021-01-24', '2021-01-31', '2021-02-07'],
#       dtype='object', length=261)

# %%
words_final = pd.DataFrame(columns=['product_category_name','2016-02-21','2016-02-28','2016-03-06','2016-03-13','2016-03-20','2016-03-27','2016-04-03','2016-04-10','2016-04-17','2016-04-24','2016-05-01','2016-05-08','2016-05-15','2016-05-22','2016-05-29','2016-06-05','2016-06-12','2016-06-19','2016-06-26','2016-07-03','2016-07-10','2016-07-17','2016-07-24','2016-07-31','2016-08-07','2016-08-14','2016-08-21','2016-08-28','2016-09-04','2016-09-11','2016-09-18','2016-09-25','2016-10-02','2016-10-09','2016-10-16','2016-10-23','2016-10-30','2016-11-06','2016-11-13','2016-11-20','2016-11-27','2016-12-04','2016-12-11','2016-12-18','2016-12-25','2017-01-01','2017-01-08','2017-01-15','2017-01-22','2017-01-29','2017-02-05','2017-02-12','2017-02-19','2017-02-26','2017-03-05','2017-03-12','2017-03-19','2017-03-26','2017-04-02','2017-04-09','2017-04-16','2017-04-23','2017-04-30','2017-05-07','2017-05-14','2017-05-21','2017-05-28','2017-06-04','2017-06-11','2017-06-18','2017-06-25','2017-07-02','2017-07-09','2017-07-16','2017-07-23','2017-07-30','2017-08-06','2017-08-13','2017-08
        words_final=pd.concat([words_final,csv], ignore_index=True)
    except:
        pass

# %%
words_final
# Out:
#                                product_category_name 2016-02-21 2016-02-28  \
# 0                          eletroportateis: (Brasil)          0         15
# 1                         eletrodomesticos: (Brasil)         18         26
# 2                              eletronicos: (Brasil)         78         65
# 3                      moveis e escritorio: (Brasil)         68         50
# 4                         telefonia e fixa: (Brasil)          0          0
# 5                     ferramentas e jardim: (Brasil)          0          0
# 6                           market e place: (Brasil)          0          0
# 7                                    audio: (Brasil)         67         59
# 8                         consoles e games: (Brasil)         97          0
# 9    construcao e ferramentas e construcao: (Brasil)          0          0
# 10                               papelaria: (Brasil)         45         38
# 11                              pet e shop: (Brasil)         67         47
# 12  construcao e ferramentas e ferramentas: (Brasil)          0         47
# 13                                  flores: (Brasil)         72         78
# 14         agro e industria e e e comercio: (Brasil)         33          0
# 15                                     pcs: (Brasil)         66         49
# 16                           moveis e sala: (Brasil)         31         61
# 17                 instrumentos e musicais: (Brasil)         29         47
# 18                         moveis e quarto: (Brasil)         78         48
# 19                                   artes: (Brasil)         97         97
# 20                       casa e construcao: (Brasil)         35         17
# 21                               alimentos: (Brasil)         89         90
# 22                                 bebidas: (Brasil)         50         48
# 23                             cine e foto: (Brasil)        100         33
# 24                            la e cuisine: (Brasil)          0          0
# 25                  artes e e e artesanato: (Brasil)         51         50
# 26                       fraldas e higiene: (Brasil)          0          0
# 27                                  musica: (Brasil)         90         86
# 28                     alimentos e bebidas: (Brasil)         70         31
# 29                 utilidades e domesticas: (Brasil)          0         44
# 30                            climatizacao: (Brasil)         14         27
# 31                              perfumaria: (Brasil)         44         65
# 32                   artigos e de e festas: (Brasil)         35         35
# 33                informatica e acessorios: (Brasil)          0         34
# 34                              automotivo: (Brasil)         77         77
# 35                         casa e conforto: (Brasil)         38         19
# 36                          beleza e saude: (Brasil)         58         48
# 37                         esporte e lazer: (Brasil)         95         42
# 38                     cama e mesa e banho: (Brasil)         35         53
#
#    2016-03-06 2016-03-13 2016-03-20 2016-03-27 2016-04-03 2016-04-10  \
# 0          47         46         32         31          0         30
# 1          27         27         23         23         23         30
# 2          77         67         73         78         71         74
# 3          68         34         70         50         17         33
# 4          19         37         20          0          0         18
# 5           0          0          0          0         50          0
# 6          21         21          0         21         64          0
# 7          63         97         76         59         58         79
# 8           0          0         50          0          0          0
# 9           0          0          0          0          0         46
# 10         35         36         27         30         32         33
# 11         48         45         58         37         68         67
# 12          0          0         49          0         47          0
# 13         90         72         71         72         77         79
# 14         33          0          0          0          0          0
# 15         71         78         58         61         53         56
# 16         41         80         21         60         51         89
# 17         43         33         40         80         57         46
# 18         20         39         30         29         86         47
# 19         99         94         75         93         91         91
# 20         44         69         45         35         34         60
# 21         91         90         82         97         97        100
# 22         47         51         52         52         54         60
# 23         33          0          0         33         33         64
# 24          0          0          0          0          0          0
# 25         51         25         52          0         25         49
# 26          0          0          0         37          0          0
# 27         87         92         92         89         91         91
# 2020-07-12                                         89
# 2020-07-19                                         62
# 2020-07-26                                         32
# 2020-08-02                                         62
# 2020-08-09                                         55
# 2020-08-16                                         46
# 2020-08-23                                         74
# 2020-08-30                                         34
# 2020-09-06                                         59
# 2020-09-13                                         44
# 2020-09-20                                         30
# 2020-09-27                                         40
# 2020-10-04                                         41
# 2020-10-11                                         30
# 2020-10-18                                         38
# 2020-10-25                                         57
# 2020-11-01                                         41
# 2020-11-08                                         39
# 2020-11-15                                         27
# 2020-11-22                                         37
# 2020-11-29                                         46
# 2020-12-06                                         63
# 2020-12-13                                         43
# 2020-12-20                                         25
# 2020-12-27                                         37
# 2021-01-03                                         35
# 2021-01-10                                         41
# 2021-01-17                                         35
# 2021-01-24                                         38
# 2021-01-31                                         35
# 2021-02-07                                         35

# %%
COLUNA DE DATA
COLUNA DE CATEGORIA
UMA COLUNA COM OS VALORES

# %%
words_final.to_csv('final.csv')

# %%
dataframegeo = pd.DataFrame()

# %%
for i in words_final.columns:
    ##deep copy = faz a copia real do dataframe, ao invez de dar um novo endereço
    df = words_final[[i]].copy()
    df.columns=['values']
    df['product_category_name']=i

# %%
for i in datageo2.columns:
    ##deep copy = faz a copia real do dataframe, ao invez de dar um novo endereço
    df = datageo2[[i]].copy()
    df.columns=['values']
    df['product_category_name']=i

# %%
df
# Out:
#                     values product_category_name
# Mato Grosso do Sul     100          climatizacao
# Goiás                   78          climatizacao
# Santa Catarina          41          climatizacao
# Pernambuco              33          climatizacao
# Bahia                   33          climatizacao
# Distrito Federal        32          climatizacao
# Ceará                   29          climatizacao
# São Paulo               26          climatizacao
# Rio Grande do Sul       25          climatizacao
# Rio de Janeiro          22          climatizacao
# Paraná                  21          climatizacao
# Minas Gerais           NaN          climatizacao
# Amapá                  NaN          climatizacao
# Rondônia               NaN          climatizacao
# Piauí                  NaN          climatizacao
# Mato Grosso            NaN          climatizacao
# Espírito Santo         NaN          climatizacao
# Pará                   NaN          climatizacao
# Paraíba                NaN          climatizacao
# Sergipe                NaN          climatizacao
# Maranhão               NaN          climatizacao
# Alagoas                NaN          climatizacao
# Amazonas               NaN          climatizacao
# Acre                   NaN          climatizacao
# Rio Grande do Norte    NaN          climatizacao
# Roraima                NaN          climatizacao
# Tocantins              NaN          climatizacao

# %%
for i in datageo2.columns:
    df = datageo2[[i]].copy()
    df.columns=['values']
    df['product_category_name']=i
    dataframegeo= pd.concat([dataframegeo,df])

# %%
dataframegeo.index = dataframegeo.index.rename('estado')

# %%
dataframegeo = dataframegeo.reset_index()

# %%
dataframegeo.to_sql(name='datageo', con=conn, if_exists='replace', index=False)

# %%
query =

# %%
{
   "Acre": "AC",
   "Alagoas": "AL",
   "Amapá": "AP",
   "Amazonas": "AM",
   "Bahia": "BA",
   "Ceará": "CE",
   "Distrito Federal": "DF",
   "Espírito Santo": "ES",
   "Goiás": "GO",
   "Maranhão": "MA",
   "Mato Grosso": "MT",
   "Mato Grosso do Sul": "MS",
   "Minas Gerais": "MG",
   "Pará": "PA",
   "Paraíba": "PB",
   "Paraná": "PR",
   "Pernambuco": "PE",
   "Piauí": "PI",
   "Rio de Janeiro": "RJ",
   "Rio Grande do Norte": "RN",
   "Rio Grande do Sul": "RS",
   "Rondônia": "RO",
   "Roraima": "RR",
   "Santa Catarina": "SC",
   "São Paulo": "SP",
   "Sergipe": "SE",
   "Tocantins": "TO"
}

# %%
datageo2 = datageo.set_index('product_category_name').T

# %%
datageo2.columns
# Out:
# product_category_name papelaria tablets_impressao_imagem alimentos_bebidas  \
# Mato Grosso do Sul          100                      NaN               100
# Goiás                        98                      NaN                97
# Santa Catarina               96                      NaN                97
# Pernambuco                   93                      NaN                92
# Bahia                        85                      NaN                90
# Distrito Federal             82                      NaN                87
# Ceará                        75                      NaN                84
# São Paulo                    74                      NaN                81
# Rio Grande do Sul            70                      NaN                80
# Rio de Janeiro               69                      NaN                78
# Paraná                       65                      NaN                76
# Minas Gerais                 65                      NaN                70
# Amapá                        54                      NaN                68
# Rondônia                     54                      NaN                67
# Piauí                        41                      NaN                65
# Mato Grosso                  37                      NaN                63
# Espírito Santo               36                      NaN                60
# Pará                         32                      NaN                46
# Paraíba                      31                      NaN               NaN
# Sergipe                      31                      NaN               NaN
# Maranhão                     29                      NaN               NaN
# Alagoas                      29                      NaN               NaN
# Amazonas                     28                      NaN               NaN
# Acre                         27                      NaN               NaN
# Rio Grande do Norte          24                      NaN               NaN
# Roraima                      22                      NaN               NaN
# Tocantins                    18                      NaN               NaN
#
# product_category_name construcao_ferramentas_jardim  \
# Mato Grosso do Sul                              NaN
# Goiás                                           NaN
# Santa Catarina                                  NaN
# Pernambuco                                      NaN
# Bahia                                           NaN
# Distrito Federal                                NaN
# Ceará                                           NaN
# São Paulo                                       NaN
# Rio Grande do Sul                               NaN
# Rio de Janeiro                                  NaN
# Paraná                                          NaN
# Minas Gerais                                    NaN
# Amapá                                           NaN
# Rondônia                                        NaN
# Piauí                                           NaN
# Mato Grosso                                     NaN
# Espírito Santo                                  NaN
# Pará                                            NaN
# Paraíba                                         NaN
# Sergipe                                         NaN
# Maranhão                                        NaN
# Alagoas                                         NaN
# Amazonas                                        NaN
# Acre                                            NaN
# Rio Grande do Norte                             NaN
# Roraima                                         NaN
# Tocantins                                       NaN
#
# product_category_name construcao_ferramentas_construcao utilidades_domesticas  \
# Mato Grosso do Sul                                  NaN                   100
# Goiás                                               NaN                   NaN
# Santa Catarina                                      NaN                   NaN
# Pernambuco                                          NaN                   NaN
# Bahia                                               NaN                   NaN
# Distrito Federal                                    NaN                   NaN
# Ceará                                               NaN                   NaN
# São Paulo                                           NaN                   NaN
# Rio Grande do Sul                                   NaN                   NaN
# Rio de Janeiro                                      NaN                   NaN
# Paraná                                              NaN                   NaN
# Minas Gerais                                        NaN                   NaN
# Amapá                                               NaN                   NaN
# Rondônia                                            NaN                   NaN
# Piauí                                               NaN                   NaN
# Mato Grosso                                         NaN                   NaN
# Espírito Santo                                      NaN                   NaN
# Pará                                                NaN                   NaN
# Paraíba                                             NaN                   NaN
# Sergipe                                             NaN                   NaN
# Maranhão                                            NaN                   NaN
# Alagoas                                             NaN                   NaN
# Amazonas                                            NaN                   NaN
# Acre                                                NaN                   NaN
# Rio Grande do Norte                                 NaN                   NaN
# Roraima                                             NaN                   NaN
# Tocantins                                           NaN                   NaN
#
# product_category_name agro_industria_e_comercio automotivo cama_mesa_banho  \
# Mato Grosso do Sul                          100        100             100
# Goiás                                       NaN         95              78
# Santa Catarina                              NaN         93              73
# Pernambuco                                  NaN         85              73
# Bahia                                       NaN         83              68
# Distrito Federal                            NaN         83              65
# Ceará                                       NaN         80              63
# São Paulo                                   NaN         80              63
# Rio Grande do Sul                           NaN         79              63
# Rio de Janeiro                              NaN         76              62
# Paraná                                      NaN         74              62
# Minas Gerais                                NaN         73              60
# Amapá                                       NaN         72              58
# Rondônia                                    NaN         70              55
# Piauí                                       NaN         70              55
# Mato Grosso                                 NaN         70              53
# Espírito Santo                              NaN         68              50
# Pará                                        NaN         68              48
# Paraíba                                     NaN         68             NaN
# Sergipe                                     NaN         67             NaN
# Maranhão                                    NaN         66             NaN
# Alagoas                                     NaN         60             NaN
# Amazonas                                    NaN         60             NaN
# Acre                                        NaN         56             NaN
# Rio Grande do Norte                         NaN         46             NaN
# Roraima                                     NaN         45             NaN
# Tocantins                                   NaN         37             NaN
#
# product_category_name moveis_colchao_e_estofado perfumaria esporte_lazer  \
# Mato Grosso do Sul                          NaN        100           100
# Goiás                                       NaN         45            80
# Santa Catarina                              NaN         40            78
# Pernambuco                                  NaN         40            76
# Bahia                                       NaN         36            72
# Distrito Federal                            NaN         33            69
# Ceará                                       NaN         27            67
# São Paulo                                   NaN         26            64
# Rio Grande do Sul                           NaN         25            62
# Rio de Janeiro                              NaN         24            62
# Paraná                                      NaN         24            61
# Minas Gerais                                NaN         23            60
# Amapá                                       NaN         22            58
# Rondônia                                    NaN         21            56
# Piauí                                       NaN         20            54
# Mato Grosso                                 NaN         18            51
# Espírito Santo                              NaN         18            51
# Pará                                        NaN         18            50
# Paraíba                                     NaN         18            48
# Sergipe                                     NaN         18            44
# Maranhão                                    NaN         17            44
# Alagoas                                     NaN         17            37
# Amazonas                                    NaN         16            36
# Acre                                        NaN         15            31
# Rio Grande do Norte                         NaN         15           NaN
# Roraima                                     NaN         12           NaN
# Tocantins                                   NaN        NaN           NaN
#
# product_category_name la_cuisine livros_interesse_geral moveis_quarto  \
# Mato Grosso do Sul           NaN                    NaN           100
# Goiás                        NaN                    NaN            83
# Santa Catarina               NaN                    NaN            79
# Pernambuco                   NaN                    NaN           NaN
# Bahia                        NaN                    NaN           NaN
# Distrito Federal             NaN                    NaN           NaN
# Ceará                        NaN                    NaN           NaN
# São Paulo                    NaN                    NaN           NaN
# Rio Grande do Sul            NaN                    NaN           NaN
# Rio de Janeiro               NaN                    NaN           NaN
# Paraná                       NaN                    NaN           NaN
# Minas Gerais                 NaN                    NaN           NaN
# Amapá                        NaN                    NaN           NaN
# Rondônia                     NaN                    NaN           NaN
# Piauí                        NaN                    NaN           NaN
# Mato Grosso                  NaN                    NaN           NaN
# Espírito Santo               NaN                    NaN           NaN
# Pará                         NaN                    NaN           NaN
# Paraíba                      NaN                    NaN           NaN
# Sergipe                      NaN                    NaN           NaN
# Maranhão                     NaN                    NaN           NaN
# Alagoas                      NaN                    NaN           NaN
# Amazonas                     NaN                    NaN           NaN
# Acre                         NaN                    NaN           NaN
# Rio Grande do Norte          NaN                    NaN           NaN
# Roraima                      NaN                    NaN           NaN
# Tocantins                    NaN                    NaN           NaN
#
# product_category_name cine_foto portateis_casa_forno_e_cafe cds_dvds_musicais  \
# Mato Grosso do Sul          NaN                         NaN               NaN
# Goiás                       NaN                         NaN               NaN
# Santa Catarina              NaN                         NaN               NaN
# Pernambuco                  NaN                         NaN               NaN
# Bahia                       NaN                         NaN               NaN
# Distrito Federal            NaN                         NaN               NaN
# Ceará                       NaN                         NaN               NaN
# São Paulo                   NaN                         NaN               NaN
# Rio Grande do Sul           NaN                         NaN               NaN
# Rio de Janeiro              NaN                         NaN               NaN
# Paraná                      NaN                         NaN               NaN
# Minas Gerais                NaN                         NaN               NaN
# Amapá                       NaN                         NaN               NaN
# Rondônia                    NaN                         NaN               NaN
# Piauí                       NaN                         NaN               NaN
# Mato Grosso                 NaN                         NaN               NaN
# Espírito Santo              NaN                         NaN               NaN
# Pará                        NaN                         NaN               NaN
# Paraíba                     NaN                         NaN               NaN
# Sergipe                     NaN                         NaN               NaN
# Maranhão                    NaN                         NaN               NaN
# Alagoas                     NaN                         NaN               NaN
# Amazonas                    NaN                         NaN               NaN
# Acre                        NaN                         NaN               NaN
# Rio Grande do Norte         NaN                         NaN               NaN
# Roraima                     NaN                         NaN               NaN
# Tocantins                   NaN                         NaN               NaN
#
# product_category_name fraldas_higiene artes_e_artesanato livros_importados  \
# Mato Grosso do Sul                NaN                100               NaN
# Goiás                             NaN                NaN               NaN
# Santa Catarina                    NaN                NaN               NaN
# Pernambuco                        NaN                NaN               NaN
# Bahia                             NaN                NaN               NaN
# Distrito Federal                  NaN                NaN               NaN
# Ceará                             NaN                NaN               NaN
# São Paulo                         NaN                NaN               NaN
# Rio Grande do Sul                 NaN                NaN               NaN
# Rio de Janeiro                    NaN                NaN               NaN
# Paraná                            NaN                NaN               NaN
# Minas Gerais                      NaN                NaN               NaN
# Amapá                             NaN                NaN               NaN
# Rondônia                          NaN                NaN               NaN
# Piauí                             NaN                NaN               NaN
# Mato Grosso                       NaN                NaN               NaN
# Espírito Santo                    NaN                NaN               NaN
# Pará                              NaN                NaN               NaN
# Paraíba                           NaN                NaN               NaN
# Sergipe                           NaN                NaN               NaN
# Maranhão                          NaN                NaN               NaN
# Alagoas                           NaN                NaN               NaN
# Amazonas                          NaN                NaN               NaN
# Acre                              NaN                NaN               NaN
# Rio Grande do Norte               NaN                NaN               NaN
# Roraima                           NaN                NaN               NaN
# Tocantins                         NaN                NaN               NaN
#
# product_category_name dvds_blu_ray flores bebidas livros_tecnicos  pcs  \
# Mato Grosso do Sul             NaN    100     100             NaN  100
# Goiás                          NaN     81      99             NaN   96
# Santa Catarina                 NaN     80      94             NaN   78
# Pernambuco                     NaN     74      88             NaN   77
# Bahia                          NaN     73      82             NaN   74
# Distrito Federal               NaN     73      81             NaN   73
# Ceará                          NaN     71      76             NaN   73
# São Paulo                      NaN     71      76             NaN   72
# Rio Grande do Sul              NaN     70      74             NaN   71
# Rio de Janeiro                 NaN     70      72             NaN   71
# Paraná                         NaN     70      64             NaN   69
# Minas Gerais                   NaN     69      63             NaN   67
# Amapá                          NaN     69      63             NaN   65
# Rondônia                       NaN     68      61             NaN   65
# Piauí                          NaN     68      61             NaN   65
# Mato Grosso                    NaN     67      61             NaN   64
# Espírito Santo                 NaN     66      60             NaN   64
# Pará                           NaN     64      59             NaN   63
# Paraíba                        NaN     64      59             NaN   63
# Sergipe                        NaN     63      59             NaN   62
# Maranhão                       NaN     62      58             NaN   62
# Alagoas                        NaN     62      58             NaN   58
# Amazonas                       NaN     62      56             NaN   58
# Acre                           NaN     61      55             NaN   52
# Rio Grande do Norte            NaN     61      55             NaN   52
# Roraima                        NaN     59      54             NaN   49
# Tocantins                      NaN     58      41             NaN  NaN
#
# product_category_name fashion_roupa_infanto_juvenil artigos_de_natal  \
# Mato Grosso do Sul                              NaN              NaN
# Goiás                                           NaN              NaN
# Santa Catarina                                  NaN              NaN
# Pernambuco                                      NaN              NaN
# Bahia                                           NaN              NaN
# Distrito Federal                                NaN              NaN
# Ceará                                           NaN              NaN
# São Paulo                                       NaN              NaN
# Rio Grande do Sul                               NaN              NaN
# Rio de Janeiro                                  NaN              NaN
# Paraná                                          NaN              NaN
# Minas Gerais                                    NaN              NaN
# Amapá                                           NaN              NaN
# Rondônia                                        NaN              NaN
# Piauí                                           NaN              NaN
# Mato Grosso                                     NaN              NaN
# Espírito Santo                                  NaN              NaN
# Pará                                            NaN              NaN
# Paraíba                                         NaN              NaN
# Sergipe                                         NaN              NaN
# Maranhão                                        NaN              NaN
# Alagoas                                         NaN              NaN
# Amazonas                                        NaN              NaN
# Acre                                            NaN              NaN
# Rio Grande do Norte                             NaN              NaN
# Roraima                                         NaN              NaN
# Tocantins                                       NaN              NaN
#
# product_category_name casa_construcao eletrodomesticos_2 moveis_sala  \
# Mato Grosso do Sul                100                NaN         100
# Goiás                              23                NaN          90
# Santa Catarina                     22                NaN          85
# Pernambuco                         19                NaN          83
# Bahia                              11                NaN          80
# Distrito Federal                   11                NaN         NaN
# Ceará                               9                NaN         NaN
# São Paulo                           8                NaN         NaN
# Rio Grande do Sul                 NaN                NaN         NaN
# Rio de Janeiro                    NaN                NaN         NaN
# Paraná                            NaN                NaN         NaN
# Minas Gerais                      NaN                NaN         NaN
# Amapá                             NaN                NaN         NaN
# Rondônia                          NaN                NaN         NaN
# Piauí                             NaN                NaN         NaN
# Mato Grosso                       NaN                NaN         NaN
# Espírito Santo                    NaN                NaN         NaN
# Pará                              NaN                NaN         NaN
# Paraíba                           NaN                NaN         NaN
# Sergipe                           NaN                NaN         NaN
# Maranhão                          NaN                NaN         NaN
# Alagoas                           NaN                NaN         NaN
# Amazonas                          NaN                NaN         NaN
# Acre                              NaN                NaN         NaN
# Rio Grande do Norte               NaN                NaN         NaN
# Roraima                           NaN                NaN         NaN
# Tocantins                         NaN                NaN         NaN
#
# product_category_name instrumentos_musicais fashion_roupa_feminina  \
# Mato Grosso do Sul                      100                    NaN
# Goiás                                    98                    NaN
# Santa Catarina                           89                    NaN
# Pernambuco                               84                    NaN
# Bahia                                    83                    NaN
# Distrito Federal                         80                    NaN
# Ceará                                    78                    NaN
# São Paulo                                75                    NaN
# Rio Grande do Sul                        73                    NaN
# Rio de Janeiro                           68                    NaN
# Paraná                                   67                    NaN
# Minas Gerais                             61                    NaN
# Amapá                                    59                    NaN
# Rondônia                                NaN                    NaN
# Piauí                                   NaN                    NaN
# Mato Grosso                             NaN                    NaN
# Espírito Santo                          NaN                    NaN
# Pará                                    NaN                    NaN
# Paraíba                                 NaN                    NaN
# Sergipe                                 NaN                    NaN
# Maranhão                                NaN                    NaN
# Alagoas                                 NaN                    NaN
# Amazonas                                NaN                    NaN
# Acre                                    NaN                    NaN
# Rio Grande do Norte                     NaN                    NaN
# Roraima                                 NaN                    NaN
# Tocantins                               NaN                    NaN
#
# product_category_name fashion_esporte alimentos artes sinalizacao_e_seguranca  \
# Mato Grosso do Sul                NaN       100   100                     NaN
# Goiás                             NaN        99    73                     NaN
# Santa Catarina                    NaN        97    67                     NaN
# Pernambuco                        NaN        97    65                     NaN
# Bahia                             NaN        96    63                     NaN
# Distrito Federal                  NaN        95    63                     NaN
# Ceará                             NaN        93    61                     NaN
# São Paulo                         NaN        92    60                     NaN
# Rio Grande do Sul                 NaN        92    58                     NaN
# Rio de Janeiro                    NaN        89    58                     NaN
# Paraná                            NaN        89    58                     NaN
# Minas Gerais                      NaN        89    57                     NaN
# Amapá                             NaN        89    57                     NaN
# Rondônia                          NaN        88    57                     NaN
# Piauí                             NaN        87    56                     NaN
# Mato Grosso                       NaN        87    56                     NaN
# Espírito Santo                    NaN        86    56                     NaN
# Pará                              NaN        85    56                     NaN
# Paraíba                           NaN        84    55                     NaN
# Sergipe                           NaN        84    52                     NaN
# Maranhão                          NaN        83    52                     NaN
# Alagoas                           NaN        80    51                     NaN
# Amazonas                          NaN        80    50                     NaN
# Acre                              NaN        78    49                     NaN
# Rio Grande do Norte               NaN        76    49                     NaN
# Roraima                           NaN        76    46                     NaN
# Tocantins                         NaN        75    41                     NaN
#
# product_category_name industria_comercio_e_negocios  \
# Mato Grosso do Sul                              NaN
# Goiás                                           NaN
# Santa Catarina                                  NaN
# Pernambuco                                      NaN
# Bahia                                           NaN
# Distrito Federal                                NaN
# Ceará                                           NaN
# São Paulo                                       NaN
# Rio Grande do Sul                               NaN
# Rio de Janeiro                                  NaN
# Paraná                                          NaN
# Minas Gerais                                    NaN
# Amapá                                           NaN
# Rondônia                                        NaN
# Piauí                                           NaN
# Mato Grosso                                     NaN
# Espírito Santo                                  NaN
# Pará                                            NaN
# Paraíba                                         NaN
# Sergipe                                         NaN
# Maranhão                                        NaN
# Alagoas                                         NaN
# Amazonas                                        NaN
# Acre                                            NaN
# Rio Grande do Norte                             NaN
# Roraima                                         NaN
# Tocantins                                       NaN
#
# product_category_name fashion_underwear_e_moda_praia  \
# Mato Grosso do Sul                               NaN
# Goiás                                            NaN
# Santa Catarina                                   NaN
# Pernambuco                                       NaN
# Bahia                                            NaN
# Distrito Federal                                 NaN
# Ceará                                            NaN
# São Paulo                                        NaN
# Rio Grande do Sul                                NaN
# Rio de Janeiro                                   NaN
# Paraná                                           NaN
# Minas Gerais                                     NaN
# Amapá                                            NaN
# Rondônia                                         NaN
# Piauí                                            NaN
# Mato Grosso                                      NaN
# Espírito Santo                                   NaN
# Pará                                             NaN
# Paraíba                                          NaN
# Sergipe                                          NaN
# Maranhão                                         NaN
# Alagoas                                          NaN
# Amazonas                                         NaN
# Acre                                             NaN
# Rio Grande do Norte                              NaN
# Roraima                                          NaN
# Tocantins                                        NaN
#
# product_category_name construcao_ferramentas_seguranca  \
# Mato Grosso do Sul                                 NaN
# Goiás                                              NaN
# Santa Catarina                                     NaN
# Pernambuco                                         NaN
# Bahia                                              NaN
# Distrito Federal                                   NaN
# Ceará                                              NaN
# São Paulo                                          NaN
# Rio Grande do Sul                                  NaN
# Rio de Janeiro                                     NaN
# Paraná                                             NaN
# Minas Gerais                                       NaN
# Amapá                                              NaN
# Rondônia                                           NaN
# Piauí                                              NaN
# Mato Grosso                                        NaN
# Espírito Santo                                     NaN
# Pará                                               NaN
# Paraíba                                            NaN
# Sergipe                                            NaN
# Maranhão                                           NaN
# Alagoas                                            NaN
# Amazonas                                           NaN
# Acre                                               NaN
# Rio Grande do Norte                                NaN
# Roraima                                            NaN
# Tocantins                                          NaN
#
# product_category_name construcao_ferramentas_iluminacao audio  \
# Mato Grosso do Sul                                  NaN   100
# Goiás                                               NaN   100
# Santa Catarina                                      NaN    96
# Pernambuco                                          NaN    95
# Bahia                                               NaN    95
# Distrito Federal                                    NaN    95
# Ceará                                               NaN    95
# São Paulo                                           NaN    94
# Rio Grande do Sul                                   NaN    94
# Rio de Janeiro                                      NaN    93
# Paraná                                              NaN    93
# Minas Gerais                                        NaN    93
# Amapá                                               NaN    92
# Rondônia                                            NaN    92
# Piauí                                               NaN    92
# Mato Grosso                                         NaN    91
# Espírito Santo                                      NaN    90
# Pará                                                NaN    90
# Paraíba                                             NaN    90
# Sergipe                                             NaN    90
# Maranhão                                            NaN    87
# Alagoas                                             NaN    87
# Amazonas                                            NaN    84
# Acre                                                NaN    84
# Rio Grande do Norte                                 NaN    83
# Roraima                                             NaN    82
# Tocantins                                           NaN    80
#
# product_category_name construcao_ferramentas_ferramentas casa_conforto  \
# Mato Grosso do Sul                                   NaN           100
# Goiás                                                NaN            81
# Santa Catarina                                       NaN            61
# Pernambuco                                           NaN            44
# Bahia                                                NaN            41
# Distrito Federal                                     NaN            34
# Ceará                                                NaN            31
# São Paulo                                            NaN            29
# Rio Grande do Sul                                    NaN            27
# Rio de Janeiro                                       NaN           NaN
# Paraná                                               NaN           NaN
# Minas Gerais                                         NaN           NaN
# Amapá                                                NaN           NaN
# Rondônia                                             NaN           NaN
# Piauí                                                NaN           NaN
# Mato Grosso                                          NaN           NaN
# Espírito Santo                                       NaN           NaN
# Pará                                                 NaN           NaN
# Paraíba                                              NaN           NaN
# Sergipe                                              NaN           NaN
# Maranhão                                             NaN           NaN
# Alagoas                                              NaN           NaN
# Amazonas                                             NaN           NaN
# Acre                                                 NaN           NaN
# Rio Grande do Norte                                  NaN           NaN
# Roraima                                              NaN           NaN
# Tocantins                                            NaN           NaN
#
# product_category_name consoles_games eletrodomesticos  \
# Mato Grosso do Sul               NaN              100
# Goiás                            NaN               85
# Santa Catarina                   NaN               80
# Pernambuco                       NaN               77
# Bahia                            NaN               76
# Distrito Federal                 NaN               73
# Ceará                            NaN               72
# São Paulo                        NaN               68
# Rio Grande do Sul                NaN               68
# Rio de Janeiro                   NaN               66
# Paraná                           NaN               63
# Minas Gerais                     NaN               62
# Amapá                            NaN               58
# Rondônia                         NaN               57
# Piauí                            NaN               56
# Mato Grosso                      NaN               55
# Espírito Santo                   NaN               55
# Pará                             NaN               54
# Paraíba                          NaN               52
# Sergipe                          NaN               50
# Maranhão                         NaN               50
# Alagoas                          NaN               50
# Amazonas                         NaN               49
# Acre                             NaN               46
# Rio Grande do Norte              NaN               43
# Roraima                          NaN               40
# Tocantins                        NaN               33
#
# product_category_name fashion_bolsas_e_acessorios beleza_saude  \
# Mato Grosso do Sul                            NaN          100
# Goiás                                         NaN           62
# Santa Catarina                                NaN           44
# Pernambuco                                    NaN           42
# Bahia                                         NaN           41
# Distrito Federal                              NaN           41
# Ceará                                         NaN           38
# São Paulo                                     NaN           36
# Rio Grande do Sul                             NaN           34
# Rio de Janeiro                                NaN           34
# Paraná                                        NaN           32
# Minas Gerais                                  NaN           27
# Amapá                                         NaN          NaN
# Rondônia                                      NaN          NaN
# Piauí                                         NaN          NaN
# Mato Grosso                                   NaN          NaN
# Espírito Santo                                NaN          NaN
# Pará                                          NaN          NaN
# Paraíba                                       NaN          NaN
# Sergipe                                       NaN          NaN
# Maranhão                                      NaN          NaN
# Alagoas                                       NaN          NaN
# Amazonas                                      NaN          NaN
# Acre                                          NaN          NaN
# Rio Grande do Norte                           NaN          NaN
# Roraima                                       NaN          NaN
# Tocantins                                     NaN          NaN
#
# product_category_name informatica_acessorios eletroportateis  \
# Mato Grosso do Sul                       100             100
# Goiás                                    NaN              80
# Santa Catarina                           NaN              69
# Pernambuco                               NaN              68
# Bahia                                    NaN              65
# Distrito Federal                         NaN              61
# Ceará                                    NaN              60
# São Paulo                                NaN              60
# Rio Grande do Sul                        NaN              55
# Rio de Janeiro                           NaN              47
# Paraná                                   NaN             NaN
# Minas Gerais                             NaN             NaN
# Amapá                                    NaN             NaN
# Rondônia                                 NaN             NaN
# Piauí                                    NaN             NaN
# Mato Grosso                              NaN             NaN
# Espírito Santo                           NaN             NaN
# Pará                                     NaN             NaN
# Paraíba                                  NaN             NaN
# Sergipe                                  NaN             NaN
# Maranhão                                 NaN             NaN
# Alagoas                                  NaN             NaN
# Amazonas                                 NaN             NaN
# Acre                                     NaN             NaN
# Rio Grande do Norte                      NaN             NaN
# Roraima                                  NaN             NaN
# Tocantins                                NaN             NaN
#
# product_category_name artigos_de_festas ferramentas_jardim pet_shop  \
# Mato Grosso do Sul                  100                NaN      100
# Goiás                               NaN                NaN       99
# Santa Catarina                      NaN                NaN       95
# Pernambuco                          NaN                NaN       92
# Bahia                               NaN                NaN       90
# Distrito Federal                    NaN                NaN       90
# Ceará                               NaN                NaN       80
# São Paulo                           NaN                NaN       77
# Rio Grande do Sul                   NaN                NaN       72
# Rio de Janeiro                      NaN                NaN       69
# Paraná                              NaN                NaN       67
# Minas Gerais                        NaN                NaN       58
# Amapá                               NaN                NaN       56
# Rondônia                            NaN                NaN       46
# Piauí                               NaN                NaN       43
# Mato Grosso                         NaN                NaN       43
# Espírito Santo                      NaN                NaN       42
# Pará                                NaN                NaN       40
# Paraíba                             NaN                NaN       36
# Sergipe                             NaN                NaN       33
# Maranhão                            NaN                NaN       31
# Alagoas                             NaN                NaN      NaN
# Amazonas                            NaN                NaN      NaN
# Acre                                NaN                NaN      NaN
# Rio Grande do Norte                 NaN                NaN      NaN
# Roraima                             NaN                NaN      NaN
# Tocantins                           NaN                NaN      NaN
#
# product_category_name cool_stuff fashion_calcados fashion_roupa_masculina  \
# Mato Grosso do Sul           NaN              NaN                     NaN
# Goiás                        NaN              NaN                     NaN
# Santa Catarina               NaN              NaN                     NaN
# Pernambuco                   NaN              NaN                     NaN
# Bahia                        NaN              NaN                     NaN
# Distrito Federal             NaN              NaN                     NaN
# Ceará                        NaN              NaN                     NaN
# São Paulo                    NaN              NaN                     NaN
# Rio Grande do Sul            NaN              NaN                     NaN
# Rio de Janeiro               NaN              NaN                     NaN
# Paraná                       NaN              NaN                     NaN
# Minas Gerais                 NaN              NaN                     NaN
# Amapá                        NaN              NaN                     NaN
# Rondônia                     NaN              NaN                     NaN
# Piauí                        NaN              NaN                     NaN
# Mato Grosso                  NaN              NaN                     NaN
# Espírito Santo               NaN              NaN                     NaN
# Pará                         NaN              NaN                     NaN
# Paraíba                      NaN              NaN                     NaN
# Sergipe                      NaN              NaN                     NaN
# Maranhão                     NaN              NaN                     NaN
# Alagoas                      NaN              NaN                     NaN
# Amazonas                     NaN              NaN                     NaN
# Acre                         NaN              NaN                     NaN
# Rio Grande do Norte          NaN              NaN                     NaN
# Roraima                      NaN              NaN                     NaN
# Tocantins                    NaN              NaN                     NaN
#
# product_category_name telefonia_fixa malas_acessorios moveis_escritorio  \
# Mato Grosso do Sul               NaN              NaN               100
# Goiás                            NaN              NaN               100
# Santa Catarina                   NaN              NaN                91
# Pernambuco                       NaN              NaN               NaN
# Bahia                            NaN              NaN               NaN
# Distrito Federal                 NaN              NaN               NaN
# Ceará                            NaN              NaN               NaN
# São Paulo                        NaN              NaN               NaN
# Rio Grande do Sul                NaN              NaN               NaN
# Rio de Janeiro                   NaN              NaN               NaN
# Paraná                           NaN              NaN               NaN
# Minas Gerais                     NaN              NaN               NaN
# Amapá                            NaN              NaN               NaN
# Rondônia                         NaN              NaN               NaN
# Piauí                            NaN              NaN               NaN
# Mato Grosso                      NaN              NaN               NaN
# Espírito Santo                   NaN              NaN               NaN
# Pará                             NaN              NaN               NaN
# Paraíba                          NaN              NaN               NaN
# Sergipe                          NaN              NaN               NaN
# Maranhão                         NaN              NaN               NaN
# Alagoas                          NaN              NaN               NaN
# Amazonas                         NaN              NaN               NaN
# Acre                             NaN              NaN               NaN
# Rio Grande do Norte              NaN              NaN               NaN
# Roraima                          NaN              NaN               NaN
# Tocantins                        NaN              NaN               NaN
#
# product_category_name eletronicos climatizacao
# Mato Grosso do Sul            100          100
# Goiás                          80           78
# Santa Catarina                 70           41
# Pernambuco                     56           33
# Bahia                          56           33
# Distrito Federal               48           32
# Ceará                          47           29
# São Paulo                      45           26
# Rio Grande do Sul              44           25
# Rio de Janeiro                 43           22
# Paraná                         42           21
# Minas Gerais                   42          NaN
# Amapá                          40          NaN
# Rondônia                       39          NaN
# Piauí                          37          NaN
# Mato Grosso                    37          NaN
# Espírito Santo                 36          NaN
# Pará                           36          NaN
# Paraíba                        35          NaN
# Sergipe                        35          NaN
# Maranhão                       35          NaN
# Alagoas                        34          NaN
# Amazonas                       34          NaN
# Acre                           34          NaN
# Rio Grande do Norte            33          NaN
# Roraima                        33          NaN
# Tocantins                      31          NaN

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
results = pool.map(fazer_word, palavra)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-153-8fd588b002e5> in <module>
# ----> 1 results = pool.map(fazer_word, palavra)
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
results = pool.map(download, my_range)

# %%
pool.terminate()

# %%
.product_category_name = datageo['product_category_name'].str.split(':').str[0].str.replace(' e ','_')

# %%
df= pd.DataFrame(columns=['resposta'])
for i in range(len(rows)):

    print(f"{' e '.join(rows[i][0:1][0].split('_'))}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4120637579bc> in <module>
#       1 df= pd.DataFrame(columns=['resposta'])
# ----> 2 for i in range(len(rows)):
#       3
#       4     print(f"{' e '.join(rows[i][0:1][0].split('_'))}")
#
# NameError: name 'rows' is not defined

# %%
df
# Out:
# Empty DataFrame
# Columns: [resposta]
# Index: []

# %%
#driver = webdriver.Chrome(executable_path=chrome_path)
df_final = pd.DataFrame(columns=['fb_tamanho','cargo','tamanho_cargo','categoria','nome','pais','publico'])
url = 'https://www.facebook.com/'
driver = webdriver.Safari()
driver.get(url) 
time.sleep(0.5)
elem = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div/div/div[2]/div/div[1]/form/div[1]/div[1]/input')
elem.send_keys('pepauulofelix@hotmail.com')
elem = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div/div/div[2]/div/div[1]/form/div[1]/div[2]/div/input')
elem.send_keys('123456!@#$%ˆ')
elem.send_keys(Keys.RETURN)
time.sleep(3)
#elem = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/form/div[2]/label/input')
#elem.click()
time.sleep(2)
url = 'https://www.facebook.com/ads/audience-insights/people?act=1363877177278067&age=18-'
driver.get(url) 
time.sleep(3)
elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[2]/ul/li/div/div/div/div[2]/div[2]/div/span/label/input')

for i in range(len(rows)):
    try:
        #elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[2]/ul/li/div/div/div/div[2]/div[2]/div/span/label/input')  
        time.sleep(3)
        elem.send_keys(' e '.join(rows[i][0:1][0].split('_')))
        time.sleep(1)
        
        elem.send_keys(Keys.RETURN)
        time.sleep(3)
        ###
        
        ### resposta do facebook do tamanho do publico
        resposta = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[1]/div[1]/div/span').text
        df1=pd.DataFrame([resposta])
        df1.columns=['tamanho']
        
        dff=pd.concat([dff,df1],ignore_index=True)
        elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/thead/tr/th[2]')
        elem.click()
        time.sleep(2)
        ###tamanho do publico 
        ###concat com cada um
        cargo1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[1]/td[1]/span').text
        
        tamanho1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[1]/td[2]/div/div[1]').text
        
        cargo2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[2]/td[1]/span').text
        
        tamanho2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[2]/td[2]/div/div[1]').text
        
        cargo3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[3]/td[1]/span').text
        
        tamanho3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[3]/td[2]/div/div[1]').text
        
        elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[1]/div[4]/ul/li[2]/span/a')
        
        elem.click()
        time.sleep(3.5)
        ###
        ###categoria do publico,nome
        ###concat com cada m
        categoria1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[1]/td[2]').text
        
        nome_cat1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[1]/td[3]/div/span/a').text
        
        categoria2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[2]/td[2]').text
        
        nome_cat2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[2]/td[3]/div/span/a').text
        
        categoria3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[3]/td[2]').text
        
        nome_cat3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[3]/td[3]/div/span/a').text
                                                 
        elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[1]/div[4]/ul/li[3]/span/a')
        
        elem.click()
        time.sleep(2)
        
        elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[1]/a[2]/span')
        elem.click()
        time.sleep(2)
        
        elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[1]/a[2]/span')
        elem.click()
        time.sleep(2)
        
        elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/thead/tr/th[2]/div/div[1]')
        elem.click()
        time.sleep(2)
        ###
        
        ###publico e pais
        ### pais possui uma porcentagemm
        ###concat com o pais1 com o publico 1 e assim por diante
        pais1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[1]/td[1]').text
        publico1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[1]/td[1]').text
        pais2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[1]/td[2]/div/div[1]').text
        publico2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[2]/td[1]').text
        pais3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[2]/td[2]/div/div[1]').text
        publico3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[3]/td[1]').text
        pais4 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div[1]/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[3]/td[2]/div/div[1]').text      
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-202-cc02e6b64d07> in <module>
#       2 df_final = pd.DataFrame(columns=['fb_tamanho','cargo','tamanho_cargo','categoria','nome','pais','publico'])
#       3 url = 'https://www.facebook.com/'
# ----> 4 driver = webdriver.Safari()
#       5 driver.get(url)
#       6 time.sleep(0.5)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/safari/webdriver.py in __init__(self, port, executable_path, reuse_service, desired_capabilities, quiet, keep_alive, service_args)
#      60                                           keep_alive=keep_alive)
#      61
# ---> 62         RemoteWebDriver.__init__(
#      63             self,
#      64             command_executor=executor,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# SessionNotCreatedException: Message: Could not create a session: The Safari instance is already paired with another WebDriver session.

# %%
elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[2]/ul/li/div/div/div/div[2]/div[1]/ul/li[2]/ul/div/li/span/button/span[2]/i')
elem.click()
time.sleep(2)
# Out:
# 'Esportes'

# %%
for i in range(len(rows.T)):
    print('oi')
# Out:
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi

# %%
range(rows)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-438b5ba06fcf> in <module>
# ----> 1 range(rows)
#
# TypeError: 'DataFrame' object cannot be interpreted as an integer

# %%
df_final = pd.DataFrame(columns=['fb_tamanho','cargo','tamanho_cargo','categoria','nome','pais','publico'])
dff = pd.DataFrame(columns=['tamanho'])

url = 'https://www.facebook.com/'
driver = webdriver.Safari()
driver.get(url) 
time.sleep(0.5)
elem = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div/div/div[2]/div/div[1]/form/div[1]/div[1]/input')
elem.send_keys('pepauulofelix@hotmail.com')
elem = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div/div/div[2]/div/div[1]/form/div[1]/div[2]/div/input')
elem.send_keys('123456!@#$%ˆ')
elem.send_keys(Keys.RETURN)
time.sleep(3)
#elem = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/form/div[2]/label/input')
#elem.click()
time.sleep(2)
url = 'https://www.facebook.com/ads/audience-insights/people?act=1363877177278067&age=18-'
driver.get(url) 


for i in range(len(rows.T)):
    
    time.sleep(3)
    elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[2]/ul/li/div/div/div/div[2]/div[2]/div/span/label/input')
    pesquisa = ' e '.join(rows[i][0:1][0].split('_'))

#elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[2]/ul/li/div/div/div/div[2]/div[2]/div/span/label/input')  
    time.sleep(2)
    elem.send_keys(pesquisa)
    time.sleep(1)

    elem.send_keys(Keys.RETURN)
    time.sleep(3)
    ###

    ### resposta do facebook do tamanho do publico
    resposta = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[1]/div[1]/div/span').text
    df1=pd.DataFrame([resposta]).T
    df1.columns=['tamanho']
    dff=pd.concat([dff,df1],ignore_index=True)
    driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-68-64805cbaf103> in <module>
#      27 #elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[2]/ul/li/div/div/div/div[2]/div[2]/div/span/label/input')
#      28     time.sleep(2)
# ---> 29     elem.send_keys(pesquisa)
#      30     time.sleep(1)
#      31
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in send_keys(self, *value)
#     475                 value = self._upload(local_file)
#     476
# --> 477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
#     479                        'value': keys_to_typing(value)})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# InvalidSessionIdException: Message:

# %%
df1
# Out:
#   tamanho
# 0

# %%
dff
# Out:
#                          tamanho
# 0        900 mil — 1 mi pessoas
# 1
# 2
# 3
# 4
# 5
# 6   Mais de 1 bilhão de pessoas
# 7
# 8         10 mi — 15 mi pessoas
# 9
# 10
# 11      70 mil — 80 mil pessoas
# 12        45 mi — 50 mi pessoas
# 13
# 14      450 mi — 500 mi pessoas
# 15
# 16
# 17
# 18  Mais de 1 bilhão de pessoas
# 19
# 20        60 mi — 70 mi pessoas
# 21
# 22

# %%
pesquisa = ' e '.join(rows[0][0:1][0].split('_'))
pesquisa
# Out:
# 'beleza e saude'

# %%
elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/thead/tr/th[2]')
    elem.click()
    time.sleep(2)
    ###tamanho do publico 
    ###concat com cada um
    cargo1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[1]/td[1]/span').text
    
    tamanho1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[1]/td[2]/div/div[1]').text
    
    cargo2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[2]/td[1]/span').text
    
    tamanho2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[2]/td[2]/div/div[1]').text
    
    cargo3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[3]/td[1]/span').text
    
    tamanho3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[5]/div[2]/div/div[2]/table/tbody/tr[3]/td[2]/div/div[1]').text
    
    elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[1]/div[4]/ul/li[2]/span/a')
    
    elem.click()
    time.sleep(3.5)
    ###
    ###categoria do publico,nome
    ###concat com cada m
    categoria1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[1]/td[2]').text
    
    nome_cat1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[1]/td[3]/div/span/a').text
    
    categoria2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[2]/td[2]').text
    
    nome_cat2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[2]/td[3]/div/span/a').text
    
    categoria3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[3]/td[2]').text
    
    nome_cat3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div[2]/div/div[2]/table/tbody/tr[3]/td[3]/div/span/a').text
                                             
    elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[1]/div[4]/ul/li[3]/span/a')
    
    elem.click()
    time.sleep(2)
    
    elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[1]/a[2]/span')
    elem.click()
    time.sleep(2)
    
    elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[1]/a[2]/span')
    elem.click()
    time.sleep(2)
    
    elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/thead/tr/th[2]/div/div[1]')
    elem.click()
    time.sleep(2)
    ###
    
    ###publico e pais
    ### pais possui uma porcentagemm
    ###concat com o pais1 com o publico 1 e assim por diante
    pais1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[1]/td[1]').text
    publico1 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[1]/td[1]').text
    pais2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[1]/td[2]/div/div[1]').text
    publico2 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[2]/td[1]').text
    pais3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[2]/td[2]/div/div[1]').text
    publico3 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[3]/td[1]').text
    pais4 = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div[1]/span/div/div[4]/div[2]/div/div/div[2]/div/div[2]/table/tbody/tr[3]/td[2]/div/div[1]').text

# %%
df_final = pd.DataFrame(columns=['fb_tamanho','cargo','tamanho_cargo','categoria','nome','pais','publico'])
dff = pd.DataFrame(columns=['tamanho'])
url = 'https://www.facebook.com/'
driver = webdriver.Safari()
driver.get(url) 
time.sleep(0.5)
elem = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div/div/div[2]/div/div[1]/form/div[1]/div[1]/input')
elem.send_keys('pepauulofelix@hotmail.com')
elem = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div/div/div[2]/div/div[1]/form/div[1]/div[2]/div/input')
elem.send_keys('123456!@#$%ˆ')
elem.send_keys(Keys.RETURN)
time.sleep(3)
#elem = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/form/div[2]/label/input')
#elem.click()
time.sleep(2)
url = 'https://www.facebook.com/ads/audience-insights/people?act=1363877177278067&age=18-'
driver.get(url) 
time.sleep(3)


for i in range(len(rows)):
    elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[2]/ul/li/div/div/div/div[2]/div[2]/div/span/label/input')
    driver.get(url) 
    time.sleep(3)
    pesquisa = ' e '.join(rows[i][0:1][0].split('_'))
    #elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[2]/ul/li/div/div/div/div[2]/div[2]/div/span/label/input')  
    time.sleep(3)
    elem.send_keys(pesquisa)
    time.sleep(1)
    
    elem.send_keys(Keys.RETURN)
    time.sleep(3)
    ###
    
    ### resposta do facebook do tamanho do publico
    resposta = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[1]/div[1]/div/span').text
    df1=pd.DataFrame([resposta])
    df1.columns=['tamanho']
    
    dff=pd.concat([dff,df1],ignore_index=True)
    elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[1]/a')
    elem.click()
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-250-a43ad0e64b21> in <module>
#      26     #elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[2]/ul/li/div/div/div/div[2]/div[2]/div/span/label/input')
#      27     time.sleep(3)
# ---> 28     elem.send_keys(pesquisa)
#      29     time.sleep(1)
#      30
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in send_keys(self, *value)
#     475                 value = self._upload(local_file)
#     476
# --> 477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
#     479                        'value': keys_to_typing(value)})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: A node reference could not be resolved: Node with identifier 'node-13D5F5A9-9801-4F97-8C4C-15073D171A1F' was not found

# %%
df_final = pd.DataFrame(columns=['fb_tamanho','cargo','tamanho_cargo','categoria','nome','pais','publico'])
dff = pd.DataFrame(columns=['tamanho'])

url = 'https://www.facebook.com/'
driver = webdriver.Safari()
driver.get(url) 
time.sleep(0.5)
elem = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div/div/div[2]/div/div[1]/form/div[1]/div[1]/input')
elem.send_keys('pepauulofelix@hotmail.com')
elem = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div/div/div[2]/div/div[1]/form/div[1]/div[2]/div/input')
elem.send_keys('123456!@#$%ˆ')
elem.send_keys(Keys.RETURN)
time.sleep(3)
#elem = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/form/div[2]/label/input')
#elem.click()
time.sleep(2)
url = 'https://www.facebook.com/ads/audience-insights/people?act=1363877177278067&age=18-'
driver.get(url) 


for i in range(len(rows.T)):
    
    time.sleep(3)
    elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[2]/ul/li/div/div/div/div[2]/div[2]/div/span/label/input')
    pesquisa = ' e '.join(rows[i][0:1][0].split('_'))

#elem = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[3]/span[3]/div/div[2]/ul/li/div/div/div/div[2]/div[2]/div/span/label/input')  
    time.sleep(2)
    elem.send_keys(pesquisa)
    time.sleep(1)

    elem.send_keys(Keys.RETURN)
    time.sleep(3)
    ###

    ### resposta do facebook do tamanho do publico
    resposta = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[2]/div/span/div/div[4]/div[1]/div[1]/div/span').text
    df1=pd.DataFrame([resposta]).T
    df1.columns=['tamanho']
    dff=pd.concat([dff,df1],ignore_index=True)
    driver.get(url)

# %%
url = 'https://app.wordstream.com/fkt/app'
driver = webdriver.Safari()
driver.maximize_window()
driver.get(url) 
timeout=3
try:
    element_present = EC.presence_of_element_located((By.XPATH, '/html/body/div[1]/form/div[1]/div/div/div/input'))
    WebDriverWait(driver, timeout).until(element_present)
    elem = driver.find_element_by_xpath('/html/body/div[1]/form/div[1]/div/div/div/input')
    elem.send_keys('iphone')
    elem.send_keys(Keys.RETURN)
    time.sleep(3)
    red = pd.read_html(url)[0]
    pd.read_html()
except TimeoutException:
    pass
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-72-6ec61f76111d> in <module>
#       2 driver = webdriver.Safari()
#       3 driver.maximize_window()
# ----> 4 driver.get(url)
#       5 timeout=3
#       6 try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message:

# %%
response = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-237b9c36258c> in <module>
# ----> 1 response = requests.get(url)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379         # Trigger any extra validation we need to do.
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#     383             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     976         # Force connect early to allow us to validate the connection.
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#     980         if not conn.is_verified:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     307     def connect(self):
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#     311
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     157
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72             if source_address:
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#      76
#
# KeyboardInterrupt:

# %%
url = 'https://app.wordstream.com/fkt/app'
driver = webdriver.Safari()
driver.maximize_window()
driver.get(url) 
timeout=5
df_final = pd.DataFrame(columns=[])

try:
    element_present = EC.presence_of_element_located((By.XPATH, '/html/body/div[1]/form/div[1]/div/div/div/input'))
    WebDriverWait(driver, timeout).until(element_present)
    elem = driver.find_element_by_xpath('/html/body/div[1]/form/div[1]/div/div/div/input')
    elem.send_keys('iphone')
    elem.send_keys(Keys.RETURN)
    time.sleep(4)
    labels = driver.find_elements(By.ID, "loading-grid")
    #formatedArray = re.findall('/S+', string)
    #print(" ".join(formatedArray))
    #red = pd.read_html(url)[0]
    #pd.read_html()
except TimeoutException:
    pass

#elem = driver.find_element_by_xpath('//*[@id="fkt-key"]')
#elem.send_keys('iphone')
#elem.send_keys(Keys.RETURN)
#time.sleep(4)

# %%
labels[0].text
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-119-aeb68c6fdec1> in <module>
# ----> 1 labels[0].text
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# InvalidSessionIdException: Message:

# %%
    x = labels[0].text.split(' ')
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-118-edf5877b12d6> in <module>
# ----> 1 x = labels[0].text.split(' ')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# InvalidSessionIdException: Message:

# %%
result = map(lambda x: x + x, numbers)
# Out:
# '                            '

# %%
x
# Out:
# ['                    ']

# %%
dff = pd.DataFrame(columns=['tamanho'])
for i in x:
    x = i.split('.')
    #df = pd.DataFrame(columns=['palavra','nivel','valor','comp'])
    df1=pd.DataFrame([x]).T
    df1.columns=['tamanho']
    dff=pd.concat([dff,df1],ignore_index=True)

# %%
dff
# Out:
#                 tamanho
# 0

# %%
df1
# Out:
#                 tamanho
# 0

# %%
import psycopg2

con = psycopg2.connect(database="olist", user="postgres", password="admin", host="127.0.0.1", port="5432")
print("Database opened successfully")
# Out:
# Database opened successfully

# %%
cur = con.cursor()
cur.execute("SELECT * FROM public.product_category_name_translation")
rows = cur.fetchall()

# %%
rows[0][0:1][0].split('_')
# Out:
# ['beleza', 'saude']

# %%
' e '.join(rows[0][0:1][0].split('_'))
# Out:
# 'beleza e saude'

# %%
for i in range(len(rows)-1):
    pesquisa = ' e '.join(rows[i][0:1][0].split('_'))
    pesquisa

# %%
pesquisa
# Out:
# 'beleza e saude'

# %%
range(len(rows)-1)
# Out:
# range(0, 70)

# %%
rows
# Out:
# [('beleza_saude', 'health_beauty'),
#  ('informatica_acessorios', 'computers_accessories'),
#  ('automotivo', 'auto'),
#  ('cama_mesa_banho', 'bed_bath_table'),
#  ('moveis_decoracao', 'furniture_decor'),
#  ('esporte_lazer', 'sports_leisure'),
#  ('perfumaria', 'perfumery'),
#  ('utilidades_domesticas', 'housewares'),
#  ('telefonia', 'telephony'),
#  ('relogios_presentes', 'watches_gifts'),
#  ('alimentos_bebidas', 'food_drink'),
#  ('bebes', 'baby'),
#  ('papelaria', 'stationery'),
#  ('tablets_impressao_imagem', 'tablets_printing_image'),
#  ('brinquedos', 'toys'),
#  ('telefonia_fixa', 'fixed_telephony'),
#  ('ferramentas_jardim', 'garden_tools'),
#  ('fashion_bolsas_e_acessorios', 'fashion_bags_accessories'),
#  ('eletroportateis', 'small_appliances'),
#  ('consoles_games', 'consoles_games'),
#  ('audio', 'audio'),
#  ('fashion_calcados', 'fashion_shoes'),
#  ('cool_stuff', 'cool_stuff'),
#  ('malas_acessorios', 'luggage_accessories'),
#  ('climatizacao', 'air_conditioning'),
#  ('construcao_ferramentas_construcao', 'construction_tools_construction'),
#  ('moveis_cozinha_area_de_servico_jantar_e_jardim',
#   'kitchen_dining_laundry_garden_furniture'),
#  ('construcao_ferramentas_jardim', 'costruction_tools_garden'),
#  ('fashion_roupa_masculina', 'fashion_male_clothing'),
#  ('pet_shop', 'pet_shop'),
#  ('moveis_escritorio', 'office_furniture'),
#  ('market_place', 'market_place'),
#  ('eletronicos', 'electronics'),
#  ('eletrodomesticos', 'home_appliances'),
#  ('artigos_de_festas', 'party_supplies'),
#  ('casa_conforto', 'home_confort'),
#  ('construcao_ferramentas_ferramentas', 'costruction_tools_tools'),
#  ('agro_industria_e_comercio', 'agro_industry_and_commerce'),
#  ('moveis_colchao_e_estofado', 'furniture_mattress_and_upholstery'),
#  ('livros_tecnicos', 'books_technical'),
#  ('casa_construcao', 'home_construction'),
#  ('instrumentos_musicais', 'musical_instruments'),
#  ('moveis_sala', 'furniture_living_room'),
#  ('construcao_ferramentas_iluminacao', 'construction_tools_lights'),
#  ('industria_comercio_e_negocios', 'industry_commerce_and_business'),
#  ('alimentos', 'food'),
#  ('artes', 'art'),
#  ('moveis_quarto', 'furniture_bedroom'),
#  ('livros_interesse_geral', 'books_general_interest'),
#  ('construcao_ferramentas_seguranca', 'construction_tools_safety'),
#  ('fashion_underwear_e_moda_praia', 'fashion_underwear_beach'),
#  ('fashion_esporte', 'fashion_sport'),
#  ('sinalizacao_e_seguranca', 'signaling_and_security'),
#  ('pcs', 'computers'),
#  ('artigos_de_natal', 'christmas_supplies'),
#  ('fashion_roupa_feminina', 'fashio_female_clothing'),
#  ('eletrodomesticos_2', 'home_appliances_2'),
#  ('livros_importados', 'books_imported'),
#  ('bebidas', 'drinks'),
#  ('cine_foto', 'cine_photo'),
#  ('la_cuisine', 'la_cuisine'),
#  ('musica', 'music'),
#  ('casa_conforto_2', 'home_comfort_2'),
#  ('portateis_casa_forno_e_cafe', 'small_appliances_home_oven_and_coffee'),
#  ('cds_dvds_musicais', 'cds_dvds_musicals'),
#  ('dvds_blu_ray', 'dvds_blu_ray'),
#  ('flores', 'flowers'),
#  ('artes_e_artesanato', 'arts_and_craftmanship'),
#  ('fraldas_higiene', 'diapers_and_hygiene'),
#  ('fashion_roupa_infanto_juvenil', 'fashion_childrens_clothes'),
#  ('seguros_e_servicos', 'security_and_services')]
